# %% [markdown]
# Example 1: This is the code to test discovery of PDE's involving multiscales. First we produce an example DATA using Ars(2,2,2) Scheme. The time step used is to produce the data is smaller by a factor of 10 than that used to fit to a PDE. While we have provide multiple examples in our manuscript, we only produce data for epsilon=1/256 in this note book. The viewer can re-run the code for other values (and parameters) by modifying the code below.

# %%
#Production of data. This is solution to linear kinetic equation:
#\partial_t g=....
#
#This code should take on the order of 10 seconds to finish running.


import sys
sys.path.insert(0, '../../Utilities/')
import scipy.io
from scipy.io import savemat
import numpy as np
import matplotlib.pyplot as plt

Lx=1.0
Nx=400
eps=1.0/256.0
Nv=16

dx = Lx/Nx
x=np.zeros([Nx,1],dtype=float)
for I in range(0,Nx):
    x[I,0] = dx*I

Nv=16

v=np.zeros([Nv,1])
wv=np.zeros([Nv,1])
v[0,0]=-0.9894009349916499325962
v[1,0]=-0.944575023073232576078
v[2,0]=-0.8656312023878317438805
v[3,0]=-0.7554044083550030338951
v[4,0]=-0.6178762444026437484467
v[5,0]=-0.4580167776572273863424
v[6,0]=-0.2816035507792589132305
v[7,0]=-0.0950125098376374401853
v[8,0]=0.0950125098376374401853
v[9,0]=0.28160355077925891323
v[10,0]=0.458016777657227386342
v[11,0]=0.617876244402643748447
v[12,0]=0.7554044083550030338951
v[13,0]=0.8656312023878317438805
v[14,0]=0.944575023073232576078
v[15,0]=0.9894009349916499325962

wv[0,0]=0.02715245941175409485178
wv[1,0]=0.0622535239386478928628
wv[2,0]=0.0951585116824927848099
wv[3,0]=0.1246289712555338720525
wv[4,0]=0.1495959888165767320815
wv[5,0]=0.169156519395002538189
wv[6,0]=0.1826034150449235888668
wv[7,0]=0.1894506104550684962854
wv[8,0]=0.189450610455068496285
wv[9,0]=0.182603415044923588867
wv[10,0]=0.1691565193950025381893
wv[11,0]=0.149595988816576732082
wv[12,0]=0.124628971255533872052
wv[13,0]=0.0951585116824927848099
wv[14,0]=0.0622535239386478928628
wv[15,0]=0.0271524594117540948518

"""
v[0,0]=-0.99518721999702136018
v[1,0]=-0.9747285559713094981984
v[2,0]=-0.9382745520027327585237
v[3,0]=-0.8864155270044010342132
v[4,0]=-0.820001985973902921954
v[5,0]=-0.7401241915785543642438
v[6,0]=-0.648093651936975569253
v[7,0]=-0.545421471388839535658
v[8,0]=-0.4337935076260451384871
v[9,0]=-0.3150426796961633743868
v[10,0]=-0.191118867473616309159
v[11,0]=-0.064056892862605626085
v[12,0]=0.064056892862605626085
v[13,0]=0.1911188674736163091586
v[14,0]=0.3150426796961633743868
v[15,0]=0.4337935076260451384871
v[16,0]=0.5454214713888395356584
v[17,0]=0.6480936519369755692525
v[18,0]=0.7401241915785543642438
v[19,0]=0.820001985973902921954
v[20,0]=0.8864155270044010342132
v[21,0]=0.9382745520027327585237
v[22,0]=0.9747285559713094981984
v[23,0]=0.99518721999702136018

wv[0,0]=0.0123412297999871995468
wv[1,0]=0.0285313886289336631813
wv[2,0]=0.0442774388174198061686
wv[3,0]=0.05929858491543678074637
wv[4,0]=0.07334648141108030573403
wv[5,0]=0.0861901615319532759172
wv[6,0]=0.0976186521041138882699
wv[7,0]=0.1074442701159656347826
wv[8,0]=0.1155056680537256013533
wv[9,0]=0.1216704729278033912045
wv[10,0]=0.1258374563468282961214
wv[11,0]=0.1279381953467521569741
wv[12,0]=0.1279381953467521569741
wv[13,0]=0.1258374563468282961214
wv[14,0]=0.121670472927803391204
wv[15,0]=0.115505668053725601353
wv[16,0]=0.1074442701159656347826
wv[17,0]=0.09761865210411388827
wv[18,0]=0.0861901615319532759172
wv[19,0]=0.073346481411080305734
wv[20,0]=0.0592985849154367807464
wv[21,0]=0.044277438817419806169
wv[22,0]=0.0285313886289336631813
wv[23,0]=0.0123412297999871995468
"""

"""
v[0,0]=-0.997263861849481563545
v[1,0]=-0.9856115115452683354002
v[2,0]=-0.9647622555875064307738
v[3,0]=-0.9349060759377396891709
v[4,0]=-0.8963211557660521239653
v[5,0]=-0.8493676137325699701337
v[6,0]=-0.794483795967942406963
v[7,0]=-0.7321821187402896803874
v[8,0]=-0.6630442669302152009751
v[9,0]=-0.5877157572407623290408
v[10,0]=-0.5068999089322293900238
v[11,0]=-0.421351276130635345364
v[12,0]=-0.3318686022821276497799
v[13,0]=-0.2392873622521370745446
v[14,0]=-0.1444719615827964934852
v[15,0]=-0.0483076656877383162348
v[16,0]=0.048307665687738316235
v[17,0]=0.1444719615827964934852
v[18,0]=0.2392873622521370745446
v[19,0]=0.33186860228212764978
v[20,0]=0.4213512761306353453641
v[21,0]=0.5068999089322293900238
v[22,0]=0.5877157572407623290408
v[23,0]=0.6630442669302152009751
v[24,0]=0.7321821187402896803874
v[25,0]=0.7944837959679424069631
v[26,0]=0.8493676137325699701337
v[27,0]=0.8963211557660521239653
v[28,0]=0.9349060759377396891709
v[29,0]=0.9647622555875064307738
v[30,0]=0.9856115115452683354002
v[31,0]=0.997263861849481563545




wv[0,0]=0.0070186100094700966004
wv[1,0]=0.0162743947309056706052
wv[2,0]=0.0253920653092620594558
wv[3,0]=0.0342738629130214331027
wv[4,0]=0.0428358980222266806569
wv[5,0]=0.050998059262376176196
wv[6,0]=0.0586840934785355471453
wv[7,0]=0.065822222776361846838
wv[8,0]=0.072345794108848506225
wv[9,0]=0.0781938957870703064717
wv[10,0]=0.0833119242269467552222
wv[11,0]=0.087652093004403811143
wv[12,0]=0.091173878695763884713
wv[13,0]=0.09384439908080456563918
wv[14,0]=0.0956387200792748594191
wv[15,0]=0.0965400885147278005668
wv[16,0]=0.0965400885147278005668
wv[17,0]=0.0956387200792748594191
wv[18,0]=0.0938443990808045656392
wv[19,0]=0.091173878695763884713
wv[20,0]=0.0876520930044038111428
wv[21,0]=0.083311924226946755222
wv[22,0]=0.078193895787070306472
wv[23,0]=0.072345794108848506225
wv[24,0]=0.065822222776361846838
wv[25,0]=0.0586840934785355471453
wv[26,0]=0.0509980592623761761962
wv[27,0]=0.0428358980222266806569
wv[28,0]=0.0342738629130214331027
wv[29,0]=0.0253920653092620594558
wv[30,0]=0.0162743947309056706052
wv[31,0]=0.0070186100094700966004
"""

rho = np.zeros([Nx,1],dtype=float)
for I in range(0,Nx):
    rho[I,0] =20*x[I,0]*(x[I,0])*(x[I,0]-1.0)*np.sin(2.0*np.pi*x[I,0])**2*np.exp(-15.0*(x[I,0]-0.5)**2.0)

g = np.zeros([Nv,Nx],dtype=float)
gk1 = np.zeros([Nv,Nx],dtype=float)
gk2 = np.zeros([Nv,Nx],dtype=float)
gk3 = np.zeros([Nv,Nx],dtype=float)
rh1 = np.zeros([Nx,1],dtype=float)
rh2 = np.zeros([Nx,1],dtype=float)
rh3 = np.zeros([Nx,1],dtype=float)

sigmaA = np.zeros([1,Nx],dtype=float)
sigmaAg = np.zeros([Nx],dtype=float)

sigmaS = np.ones([Nx],dtype=float)
for I in range(0,Nx):
    sigmaS[I]=1#-10*x[I,0]**2

G = np.zeros([Nx,1],dtype=float)
ss = np.zeros([Nx,1],dtype=float)
ssk1 = np.zeros([Nx,1],dtype=float)
ssk2 = np.zeros([Nx,1],dtype=float)
ssk3 = np.zeros([Nx,1],dtype=float)


UFgk1 = np.zeros([Nv,Nx],dtype=float)
UFgk2 = np.zeros([Nv,Nx],dtype=float)
UFgk3 = np.zeros([Nv,Nx],dtype=float)
UFg = np.zeros([Nv,Nx],dtype=float)

PUFgk1 = np.zeros([Nv,Nx],dtype=float)
PUFgk2 = np.zeros([Nv,Nx],dtype=float)
PUFgk3 = np.zeros([Nv,Nx],dtype=float)
PUFg = np.zeros([Nv,Nx],dtype=float)

Frho1 = np.zeros([Nv,Nx],dtype=float)
Frho2 = np.zeros([Nv,Nx],dtype=float)
Frho3 = np.zeros([Nv,Nx],dtype=float)
Frho = np.zeros([Nv,Nx],dtype=float)



N_s=3
A1=np.zeros([N_s,N_s],dtype=float)
c1=np.zeros([N_s,1],dtype=float)
w1=np.zeros([N_s,1],dtype=float)

A2=np.zeros([N_s,N_s],dtype=float)
c2=np.zeros([N_s,1],dtype=float)
w2=np.zeros([N_s,1],dtype=float)

#IMEX RK ARS(2,2,2)
gamma=1.0-np.sqrt(2.0)/2.0
delta=1.0-1.0/(2.0*gamma)
A1[1,0]=gamma
A1[2,0]=delta
A1[2,1]=1.0-delta
w1[0,0]=delta
w1[1,0]=1.0-delta
w1[2,0]=0.0

A2[1,1]=gamma
A2[2,1]=1.0-gamma
A2[2,2]=gamma
w2[0,0]=0.0
w2[1,0]=1.0-gamma
w2[2,0]=gamma



CFg = np.zeros([Nv,Nx],dtype=float)
PCFg = np.zeros([1,Nx],dtype=float)

gL = np.zeros([Nv,1],dtype=float)
gR = np.zeros([Nv,1],dtype=float)

gLk1 = np.zeros([Nv,1],dtype=float)
gRk1 = np.zeros([Nv,1],dtype=float)
gLk2 = np.zeros([Nv,1],dtype=float)
gRk2 = np.zeros([Nv,1],dtype=float)
gLk3 = np.zeros([Nv,1],dtype=float)
gRk3 = np.zeros([Nv,1],dtype=float)



dt=dx*dx/20


nt=400

nt*dt


Data_rho = np.zeros([Nx,int(nt)],dtype=float)
Data_g = np.zeros([Nv,Nx,int(nt)],dtype=float)

Data_Frho = np.zeros([Nv,Nx,int(nt)],dtype=float)

s = np.zeros([Nv,1],dtype=float)
ss = np.zeros([Nx,1],dtype=float)


for tt in range(0,int(nt)):
    
    Data_g[:,:,tt]=g[:,:]
    Data_rho[:,tt]=rho[:,0]
    
    gk1=g
    rh1=rho            
            
    for I in range(0,Nv):
        if v[I]>0:
            for J in range(2,Nx-1):
                UFgk1[I,J] =v[I,0]*(2.0*gk1[I,J+1]+3.0*gk1[I,J]-6.0*gk1[I,J-1]+gk1[I,J-2])/(6.0*dx)
            UFgk1[I,Nx-1] =v[I,0]*(2.0*gk1[I,0]+3.0*gk1[I,Nx-1]-6.0*gk1[I,Nx-2]+gk1[I,Nx-3])/(6.0*dx)
            UFgk1[I,1] = v[I,0]*(2.0*gk1[I,2]+3.0*gk1[I,1]-6.0*gk1[I,0]+gk1[I,Nx-1])/(6.0*dx)
            UFgk1[I,0] =v[I,0]*(2.0*gk1[I,1]+3.0*gk1[I,0]-6.0*gk1[I,Nx-1]+gk1[I,Nx-2])/(6.0*dx)          
        else:
            for J in range(1,Nx-2):
                UFgk1[I,J] =v[I,0]*(-1.0*gk1[I,J+2]+6.0*gk1[I,J+1]-3.0*gk1[I,J]-2.0*gk1[I,J-1])/(6.0*dx)
            UFgk1[I,0] = v[I,0]*(-1.0*gk1[I,2]+6.0*gk1[I,1]-3.0*gk1[I,0]-2.0*gk1[I,Nx-1])/(6.0*dx)
            UFgk1[I,Nx-2] =v[I,0]*(-1.0*gk1[I,0]+6.0*gk1[I,Nx-1]-3.0*gk1[I,Nx-2]-2.0*gk1[I,Nx-3])/(6.0*dx)
            UFgk1[I,Nx-1] =v[I,0]*(-1.0*gk1[I,1]+6.0*gk1[I,0]-3.0*gk1[I,Nx-1]-2.0*gk1[I,Nx-2])/(6.0*dx)

    for i in range(0,Nx):
        for j in range(0,Nv):
            s[j,0]=wv[j,0]*UFgk1[j,i]#
        ssk1[i,0]=sum(s)/2
    for j in range(0,Nv):
        for i in range(0,Nx):
            PUFgk1[j,i] = ssk1[i,0] 
    

    for I in range(0,Nv):
        if v[I]>0:
            for J in range(1,Nx-2):
                Frho1[I,J] =v[I,0]*(-1.0*rh1[J+2,0]+6.0*rh1[J+1,0]-3.0*rh1[J,0]-2.0*rh1[J-1,0])/(6.0*dx)
            Frho1[I,0] = v[I,0]*(-1.0*rh1[2,0]+6.0*rh1[1,0]-3.0*rh1[0,0]-2.0*rh1[Nx-1,0])/(6.0*dx)
            Frho1[I,Nx-2] =v[I,0]*(-1.0*rh1[0,0]+6.0*rh1[Nx-1,0]-3.0*rh1[Nx-2,0]-2.0*rh1[Nx-3,0])/(6.0*dx)
            Frho1[I,Nx-1] =v[I,0]*(-1.0*rh1[1,0]+6.0*rh1[0,0]-3.0*rh1[Nx-1,0]-2.0*rh1[Nx-2,0])/(6.0*dx)
        else:
            for J in range(2,Nx-1):
                Frho1[I,J] =v[I,0]*(2.0*rh1[J+1,0]+3.0*rh1[J,0]-6.0*rh1[J-1,0]+rh1[J-2,0])/(6.0*dx)
            Frho1[I,Nx-1] =v[I,0]*(2.0*rh1[0,0]+3.0*rh1[Nx-1,0]-6.0*rh1[Nx-2,0]+rh1[Nx-3,0])/(6.0*dx)
            Frho1[I,1] = v[I,0]*(2.0*rh1[2,0]+3.0*rh1[1,0]-6.0*rh1[0,0]+rh1[Nx-1,0])/(6.0*dx)
            Frho1[I,0] =v[I,0]*(2.0*rh1[1,0]+3.0*rh1[0,0]-6.0*rh1[Nx-1,0]+rh1[Nx-2,0])/(6.0*dx)           
    
    gk2=(eps**2*g-dt*A1[1,0]*(UFgk1-PUFgk1)*eps-dt*A1[1,0]*Frho1-dt*A1[1,0]*0.0*gk1*eps**2)/(eps**2+dt*A2[1,1]*1.0)   

    for I in range(0,Nv):
        if v[I]>0:
            for J in range(2,Nx-1):
                UFgk2[I,J] =v[I,0]*(2.0*gk2[I,J+1]+3.0*gk2[I,J]-6.0*gk2[I,J-1]+gk2[I,J-2])/(6.0*dx)
            UFgk2[I,Nx-1] =v[I,0]*(2.0*gk2[I,0]+3.0*gk2[I,Nx-1]-6.0*gk2[I,Nx-2]+gk2[I,Nx-3])/(6.0*dx)
            UFgk2[I,1] = v[I,0]*(2.0*gk2[I,2]+3.0*gk2[I,1]-6.0*gk2[I,0]+gk2[I,Nx-1])/(6.0*dx)
            UFgk2[I,0] =v[I,0]*(2.0*gk2[I,1]+3.0*gk2[I,0]-6.0*gk2[I,Nx-1]+gk2[I,Nx-2])/(6.0*dx)          
        else:
            for J in range(1,Nx-2):
                UFgk2[I,J] =v[I,0]*(-1.0*gk2[I,J+2]+6.0*gk2[I,J+1]-3.0*gk2[I,J]-2.0*gk2[I,J-1])/(6.0*dx)
            UFgk2[I,0] =v[I,0]*(-1.0*gk2[I,2]+6.0*gk2[I,1]-3.0*gk2[I,0]-2.0*gk2[I,Nx-1])/(6.0*dx)
            UFgk2[I,Nx-2] =v[I,0]*(-1.0*gk2[I,0]+6.0*gk2[I,Nx-1]-3.0*gk2[I,Nx-2]-2.0*gk2[I,Nx-3])/(6.0*dx)
            UFgk2[I,Nx-1] =v[I,0]*(-1.0*gk2[I,1]+6.0*gk2[I,0]-3.0*gk2[I,Nx-1]-2.0*gk2[I,Nx-2])/(6.0*dx)

    for i in range(0,Nx):
        for j in range(0,Nv):
            s[j,0]=wv[j,0]*UFgk2[j,i]#
        ssk2[i,0]=sum(s)/2
    for j in range(0,Nv):
        for i in range(0,Nx):
            PUFgk2[j,i] = ssk2[i,0] #
            
    rh2=rho-dt*A1[1,0]*(0.0*rh1-G)-dt*A2[1,1]*ssk2

    for I in range(0,Nv):        
        if v[I]>0:
            for J in range(1,Nx-2):
                Frho2[I,J] =v[I,0]*(-1.0*rh2[J+2,0]+6.0*rh2[J+1,0]-3.0*rh2[J,0]-2.0*rh2[J-1,0])/(6.0*dx)
            Frho2[I,0] = v[I,0]*(-1.0*rh2[2,0]+6.0*rh2[1,0]-3.0*rh2[0,0]-2.0*rh2[Nx-1,0])/(6.0*dx)
            Frho2[I,Nx-2] =v[I,0]*(-1.0*rh2[0,0]+6.0*rh2[Nx-1,0]-3.0*rh2[Nx-2,0]-2.0*rh2[Nx-3,0])/(6.0*dx)
            Frho2[I,Nx-1] =v[I,0]*(-1.0*rh2[1,0]+6.0*rh2[0,0]-3.0*rh2[Nx-1,0]-2.0*rh2[Nx-2,0])/(6.0*dx)    
        else:
            for J in range(2,Nx-1):
                Frho2[I,J] =v[I,0]*(2.0*rh2[J+1,0]+3.0*rh2[J,0]-6.0*rh2[J-1,0]+rh2[J-2,0])/(6.0*dx)
            Frho2[I,Nx-1] =v[I,0]*(2.0*rh2[0,0]+3.0*rh2[Nx-1,0]-6.0*rh2[Nx-2,0]+rh2[Nx-3,0])/(6.0*dx)
            Frho2[I,1] = v[I,0]*(2.0*rh2[2,0]+3.0*rh2[1,0]-6.0*rh2[0,0]+rh2[Nx-1,0])/(6.0*dx)
            Frho2[I,0] =v[I,0]*(2.0*rh2[1,0]+3.0*rh2[0,0]-6.0*rh2[Nx-1,0]+rh2[Nx-2,0])/(6.0*dx)            
    
    gk3=(eps**2*g-dt*A1[2,0]*(UFgk1-PUFgk1)*eps-dt*A1[2,0]*Frho1-dt*A1[2,1]*eps*(UFgk2-PUFgk2)-dt*A1[2,1]*Frho2-dt*A1[2,0]*gk1*0.0*eps**2-dt*A1[2,1]*0.0*gk2*eps**2-dt*A2[2,1]*1.0*gk2)/(eps**2+dt*A2[2,2]*1.0)

    for I in range(0,Nv):
        if v[I]>0:
            for J in range(2,Nx-1):
                UFgk3[I,J] =v[I,0]*(2.0*gk3[I,J+1]+3.0*gk3[I,J]-6.0*gk3[I,J-1]+gk3[I,J-2])/(6.0*dx)
            UFgk3[I,Nx-1] =v[I,0]*(2.0*gk3[I,0]+3.0*gk3[I,Nx-1]-6.0*gk3[I,Nx-2]+gk3[I,Nx-3])/(6.0*dx)
            UFgk3[I,1] = v[I,0]*(2.0*gk3[I,2]+3.0*gk3[I,1]-6.0*gk3[I,0]+gk3[I,Nx-1])/(6.0*dx)
            UFgk3[I,0] =v[I,0]*(2.0*gk3[I,1]+3.0*gk3[I,0]-6.0*gk3[I,Nx-1]+gk3[I,Nx-2])/(6.0*dx)          
        else:
            for J in range(1,Nx-2):
                UFgk3[I,J] =v[I,0]*(-1.0*gk3[I,J+2]+6.0*gk3[I,J+1]-3.0*gk3[I,J]-2.0*gk3[I,J-1])/(6.0*dx)
            UFgk3[I,0] =v[I,0]*(-1.0*gk3[I,2]+6.0*gk3[I,1]-3.0*gk3[I,0]-2.0*gk3[I,Nx-1])/(6.0*dx)
            UFgk3[I,Nx-2] =v[I,0]*(-1.0*gk3[I,0]+6.0*gk3[I,Nx-1]-3.0*gk3[I,Nx-2]-2.0*gk3[I,Nx-3])/(6.0*dx)
            UFgk3[I,Nx-1] =v[I,0]*(-1.0*gk3[I,1]+6.0*gk3[I,0]-3.0*gk3[I,Nx-1]-2.0*gk3[I,Nx-2])/(6.0*dx)        
        
    for i in range(0,Nx):
        for j in range(0,Nv):
            s[j,0]=wv[j,0]*UFgk3[j,i]
        ssk3[i,0]=sum(s)/2
    for j in range(0,Nv):
        for i in range(0,Nx):
            PUFgk3[j,i] = ssk3[i,0] 

    rh3=rho-dt*A1[2,0]*(0.0*rh1-G)-dt*A1[2,1]*(0.0*rh2-G)-dt*A2[2,1]*ssk2-dt*A2[2,2]*ssk3
        
    g1=g-dt*w1[0,0]*((UFgk1-PUFgk1)/eps+Frho1/eps**2.0+0.0*gk1)-dt*w1[1,0]*((UFgk2-PUFgk2)/eps+Frho2/eps**2.0+0.0*gk2)-dt*w2[1,0]*(1.0/eps**2.0)*gk2-dt*w2[2,0]*(1.0/eps**2.0)*gk3

    rho1=rho-dt*w1[0,0]*(0.0*rh1-G)-dt*w1[1,0]*(0.0*rh2-G)-dt*w2[1,0]*ssk2-dt*w2[2,0]*ssk3
    
    rho1=rho1
    g = g1
                
    for I in range(0,Nv):
        if v[I]>0:
            for J in range(2,Nx):
                UFg[I,J] =v[I,0]*(3.0*g[I,J]-4.0*g[I,J-1]+g[I,J-2])/(2.0*dx)
            UFg[I,1] = v[I,0]*(3.0*g[I,1]-4.0*g[I,0]+g[I,Nx-1])/(2.0*dx)
            UFg[I,0] =v[I,0]*(3.0*g[I,0]-4.0*g[I,Nx-1]+g[I,Nx-2])/(2.0*dx) 
        else:
            for J in range(0,Nx-2):
                UFg[I,J] = v[I,0]*(-1.0*g[I,J+2]+4.0*g[I,J+1]-3.0*g[I,J])/(2.0*dx)
            UFg[I,Nx-2] = v[I,0]*(-1.0*g[I,0]+4.0*g[I,Nx-1]-3.0*g[I,Nx-2])/(2.0*dx)
            UFg[I,Nx-1] =v[I,0]*(-1.0*g[I,1]+4.0*g[I,0]-3.0*g[I,Nx-1])/(2.0*dx)
        
    for i in range(0,Nx):
        for j in range(0,Nv):
            s[j,0]=wv[j,0]*UFg[j,i]#
        ss[i,0]=sum(s)/2
    for j in range(0,Nv):
        for i in range(0,Nx):
            PUFg[j,i] = ss[i,0]
           
    for I in range(0,Nv):
        if v[I]>0:
            for J in range(0,Nx-2):#
                Frho[I,J] = v[I,0]*(-1.0*rho1[J+2,0]+4.0*rho1[J+1,0]-3.0*rho1[J,0])/(2.0*dx)
            Frho[I,Nx-2] = v[I,0]*(-1.0*rho1[0,0]+4.0*rho1[Nx-1,0]-3.0*rho1[Nx-2,0])/(2.0*dx)
            Frho[I,Nx-1] =v[I,0]*(-1.0*rho1[1,0]+4.0*rho1[0,0]-3.0*rho1[Nx-1,0])/(2.0*dx)
        else:
            for J in range(2,Nx):#
                Frho[I,J] = v[I,0]*(3.0*rho1[J,0]-4.0*rho1[J-1,0]+rho1[J-2,0])/(2.0*dx)
            Frho[I,1] = v[I,0]*(3.0*rho1[1,0]-4.0*rho1[0,0]+rho1[Nx-1,0])/(2.0*dx)#
            Frho[I,0] =v[I,0]*(3.0*rho1[0,0]-4.0*rho1[Nx-1,0]+rho1[Nx-2,0])/(2.0*dx)
        
    Data_Frho[:,:,tt]=Frho[:,:]
    rho = rho1
  
print('0')
fig = plt.figure()
plt.scatter(x,rho, color='black', linewidth=3, label='Plot of rho at final time')
plt.legend()
plt.show() 

print('1')

nt_skip=10
NNN=1
Data_rho2 = np.zeros([int(Nx/NNN),int(nt/nt_skip)],dtype=float)
Data_g2 = np.zeros([Nv,int(Nx/NNN),int(nt/nt_skip)],dtype=float)
    
for I in range(0,Nv):
    for J in range(0,int(Nx/NNN)):
        for K in range(0,int(nt/nt_skip)):
            Data_g2[I,J,K]=Data_g[I,int(J*NNN),int(K*nt_skip)]
                
for J in range(0,int(Nx/NNN)):
    for K in range(0,int(nt/nt_skip)):
        Data_rho2[J,K]=Data_rho[int(NNN*J),int(K*nt_skip)]

dt=dt*nt_skip
dx=dx

savemat('data_mm.mat',{'x':x, 'u':Data_rho2,'g':Data_g2 , 'v':v, 'wv':wv, 'dt':dt, 'hx':dx })

print('Data was successfully saved')
# Out:
# 0
# 1
# Data was successfully saved

# %% [markdown]
# Now that we have data, we can run the code to figure out what this PDE is. First we run the code using the assumption that there is no scale separation. i.e. the PDE is fitted to a dictionary with O(1) terms. The Scheme used here is IMEX-BDF-2. As seen from this example, a PDE-solving numerical scheme alone will likely not produce a PDE that is close to the exact answer.

# %%
#This is for 2nd order IMEX-BDF-2 fitting.
#This scheme uses two layers
#The advection and projection operations are used to generate
#Terms for the dictionary.
#The parameter Max_order=0 means the scheme does not depend on
#epsilon and thus the epsilon output should be ignored

import sys
sys.path.insert(0, '../../Utilities/')
import scipy.io
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.io import savemat
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show
from scipy import interpolate




def coeffsrho(W2,N_layers,eps):
    if Max_orders==0:
        c_rho=0.0
        c_v_rho_x=W2[2][0,0]
    elif Max_orders==1:
        c_rho=0.0
        c_v_rho_x=W2[2][0,0]+W2[2][1,0]/eps
    elif Max_orders==2:
        c_rho=0.0
        c_v_rho_x=W2[2][0,0]+W2[2][1,0]/eps+W2[2][2,0]/eps**2
    else:
        print('not implemented')
    return c_rho,c_v_rho_x

def coeffsg(W2,N_layers,eps):
    if Max_orders==0:
        c_g=0.0
        c_v_g_x=W2[2][0,0]
        pvgx=W2[2][0,3]*W2[0][0,0]
        pvgx=pvgx+W2[2][0,5]*W2[1][0,0]
        pvgx=pvgx+W2[2][0,5]*W2[1][0,3]*W2[0][0,0]
    elif Max_orders==1:
        c_g=0.0
        c_v_g_x=W2[2][0,0]+W2[2][1,0]/eps
        pvgx=W2[2][0,3]*W2[0][0,0]+W2[2][1,3]*W2[0][1,0]/eps
        pvgx=pvgx+W2[2][0,5]*W2[1][0,0]+W2[2][1,5]*W2[1][1,0]/eps
        pvgx=pvgx+W2[2][0,5]*W2[1][0,3]*W2[0][0,0]+W2[2][1,5]*W2[1][1,3]*W2[0][1,0]/eps
    elif Max_orders==2:
        c_g=0.0
        c_v_g_x=W2[2][0,0]+W2[2][1,0]/eps+W2[2][2,0]/eps**2
        pvgx=W2[2][0,3]*W2[0][0,0]+W2[2][1,3]*W2[0][1,0]/eps+W2[2][2,3]*W2[0][2,0]/eps**2
        pvgx=pvgx+W2[2][0,5]*W2[1][0,0]+W2[2][1,5]*W2[1][1,0]/eps+W2[2][2,5]*W2[1][2,0]/eps**2
        pvgx=pvgx+W2[2][0,5]*W2[1][0,3]*W2[0][0,0]+W2[2][1,5]*W2[1][1,3]*W2[0][1,0]/eps+W2[2][2,5]*W2[1][2,3]*W2[0][2,0]/eps**2
    else:
        print('Not implemented')
    return c_g,c_v_g_x,pvgx


class PDE_CLASSIFY:
    def __init__(self,rho_extend,g,n_dat,N_layers,Nx,dt,hx,v,vextend,vplus,vplusextend,vminus,vminusextend,wv,wvextend,A1,A2,w1,w2,flag,max_epsilon,min_epsilon,weightsg0inp,weightsg1inp,weightsg2inp,wstiffginp,wstiffginp2,Max_orders,Losss):
        self.rho_extend = rho_extend
        self.vextend = vextend
        self.wvextend = wvextend
        self.g = g
        self.wv = wv
        self.Losss=Losss
        self.v=v
        self.vplus=vplus
        self.vminus=vminus
        self.vplusextend=vplusextend
        self.vminusextend=vminusextend
        self.weightsg0inp=weightsg0inp
        self.weightsg1inp=weightsg1inp
        self.weightsg2inp=weightsg2inp
        self.wstiffginp=wstiffginp
        self.wstiffginp2=wstiffginp2
        self.max_epsilon=max_epsilon
        self.min_epsilon=min_epsilon
        self.Max_orders=Max_orders
        
        self.A1=A1
        self.A2=A2
        self.w1=w1
        self.w2=w2

        self.Nx=Nx
        self.dt=dt
        self.N_layers=N_layers
        self.n_dat=n_dat
        self.hx=hx

        self.weights_g0,self.weights_g1,self.wstiffg, self.wstiffg2= self.initialize_NNg(N_layers)
        
        self.v_tf = tf.placeholder(tf.float32, shape=[None, self.v.shape[1]])
        self.rho_extend_tf = tf.placeholder(tf.float32, shape=[None, None, self.rho_extend.shape[2]])

        self.g_tf = tf.placeholder(tf.float32, shape=[None, None, self.g.shape[2]])

        self.vextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.vextend.shape[2]])
        self.vplusextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.vplusextend.shape[2]])
        self.vminusextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.vminusextend.shape[2]])
        self.wvextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.wvextend.shape[2]])
        
        # tf Graphs
        self.g_pred,self.weights_g0_tf, self.weights_g1_tf,self.wstiff_g_tf,self.wstiff_g2_tf,self.g_innerproduct,self.rho_pred,self.eps_pred = self.net_uv(self.rho_extend_tf,self.g_tf,self.vextend_tf,self.wvextend_tf)
        # Loss

        gamma=0.000001
#        gamma=0.000
        self.loss = tf.reduce_mean(tf.abs(self.g_pred))#+gamma*(tf.reduce_mean(tf.abs(self.weights_g0_tf[0]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[1]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[2]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[0]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[1]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[2])))#+tf.reduce_mean(tf.abs(self.g_pred))#+gamma*(tf.reduce_mean(tf.abs(self.weights_g0_tf[1]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[1])))#+tf.reduce_mean(tf.abs(self.weights_g0_tf[1]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[2]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[3]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[4]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[5]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[6])))+gamma*(tf.reduce_mean(tf.abs(self.weights_g1_tf[0]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[1]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[2]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[3]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[4]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[5]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[6])))#+tf.reduce_mean(tf.square(self.g_innerproduct))#+tf.reduce_mean(dt*tf.abs(self.g_innerproduct))

    # Optimizers
        self.optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
    name='Adam')   
    
        self.optimizer_Adam = tf.train.AdamOptimizer()
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss)
                
        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        init = tf.global_variables_initializer()
        self.sess.run(init)


    def initialize_NNg(self, N_layers):
        if Max_orders==0:
            weights_g0=[]
            weights_g1=[]
            initializeit=1.5
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([1,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g0.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([1,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g0.append(W_last_g)
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([1,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g1.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([1,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g1.append(W_last_g)
        elif Max_orders==1:
            weights_g0=[]
            weights_g1=[]
            initializeit=1.5
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([2,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g0.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([2,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g0.append(W_last_g)
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([2,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g1.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([2,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g1.append(W_last_g)
        elif Max_orders==2:
            weights_g0=[]
            weights_g1=[]
            initializeit=1.5
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([3,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g0.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([3,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g0.append(W_last_g)
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([3,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g1.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([3,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g1.append(W_last_g)
        else:
            print('Not implemented')
 
        wstiffg=1*tf.Variable(1.0,dtype=tf.float32)

        wstiffg2=1*tf.Variable(1.0,dtype=tf.float32)

        return weights_g0,weights_g1,wstiffg,wstiffg2




    def neural_netg(self,g,weights_g0,eps,wstiffg,v,n_dat,N_layers,Nx,dt,ns,po):
##############################################################################
#                                                                            #
#    #####       ######                            #                         #
#    #           #                                 #                         #
#    #   ###     ######   #####   #   #   ####   #####  #   #####  #####     #
#    #    #      #       #    #   #   #  #   #     #    #   #   #  #   #     #
#    #####       ######   #####   #####   #####    #    #   #####  #   #     #
#                             #                                              #
#                             ##                                             #
#                             #                                              #
##############################################################################             
            
        if (N_layers==0):
            WL=weights_g0[0]
            temp1=self.advection2g(g,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp2=self.projection(g,wvextend[:,:,0:n_dat-ns-1],ns)
            F_rhs_g=WL[po,0]*temp1+WL[po,1]*temp2
        elif (N_layers==1):
            W0=weights_g0[0]
            temp1=self.advection2g(g,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp2=self.projection(g,wvextend[:,:,0:n_dat-ns-1],ns)
            h1=W0[po,0]*temp1+W0[po,1]*temp2
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp12=self.projection(h1,wvextend[:,:,0:n_dat-ns-1],ns)
            WL=weights_g0[1]
            F_rhs_g=WL[po,0]*temp1+WL[po,1]*temp2+WL[po,2]*temp11+WL[po,3]*temp12
        elif N_layers==2:
            ns=1
            W0=weights_g0[0]
            temp1=self.advection2g(g,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp2=self.projection(g,wvextend[:,:,0:n_dat-ns-1],ns)
            h1=W0[po,0]*temp1+W0[po,1]*temp2
            W1=weights_g0[1]
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp12=self.projection(h1,wvextend[:,:,0:n_dat-ns-1],ns)
            h2=W1[po,0]*temp1+W1[po,1]*temp2+W1[po,2]*temp11+W1[po,3]*temp12
            temp111=self.advection2g(h2,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp112=self.projection(h2,wvextend[:,:,0:n_dat-ns-1],ns)
            WL=weights_g0[2]
            F_rhs_g=(WL[po,0])*temp1+(WL[po,1])*temp2+(WL[po,2])*temp11+(WL[po,3])*temp12+(WL[po,4])*temp111+(WL[po,5])*temp112
        else:
            print('Not implemented')

        return F_rhs_g, weights_g0, v
    
    def neural_netrho(self,rho_extend,weights_g1,eps,wstiffg,v,n_dat,N_layers,Nx,dt,ns,po):
##################################################################################   
#                                                                                #
#        #              ######                            #                      #
#        #              #                                 #                      #
#  ##### #####  #####   ######   #####   #   #   ####   #####  #   #####  #####  #
#  #     #   #  #   #   #       #    #   #   #  #   #     #    #   #   #  #   #  #
#  #     #   #  #####   ######   #####   #####   #####    #    #   #####  #   #  #
#                                    #                                           #
#                                    ##                                          #
#                                    #                                           #
##################################################################################        
        if N_layers==0:
            WL=weights_g1[0]
            temp1=self.advection2g(rho_extend,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            F_rhs_rho=WL[po,0]*temp1#
        elif N_layers==1:
            W0=weights_g1[0]
            temp1=self.advection2g(rho_extend,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            h1=W0[po,0]*temp1
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            WL=weights_g1[1]
            F_rhs_rho=WL[po,0]*temp1+WL[po,2]*temp11
        elif N_layers==2:
            ns=1
            W0=weights_g1[0]
            temp1=self.advection2g(rho_extend,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            h1=W0[po,0]*temp1
            W1=weights_g1[1]
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            h2=W1[po,0]*temp1+W1[po,2]*temp11
            temp111=self.advection2g(h2,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            WL=weights_g1[2]
            F_rhs_rho=(WL[po,0])*temp1+(WL[po,2])*temp11+(WL[po,4])*temp111
        else:
            print('Not implemented')
        return F_rhs_rho, weights_g1
     
    def firstderiv(self,g):
        out=(tf.roll(g,1,axis=1)-tf.roll(g,-1,axis=1))/(2.0*hx)
        return out
    
    def secondderiv(self,g):
        out=(tf.roll(g,1,axis=1)-2.0*g+tf.roll(g,-1,axis=1))/(hx*hx)
        return out
        
    def rhoOP(self,rhoextend,g):
        rhog=rhoextend*g
        return rhog
    
    def gOP(self,g,f):
        gf=g*f
        return gf
    
    def advection(self,g,vplusextend,vminusextend,vextend):
        advec=vextend*(tf.roll(g,1,axis=1)-tf.roll(g,-1,axis=1))/(2*hx)
        #        uxminustf=(g-tf.roll(g,1,axis=1))/hx
#        uxplustf=(tf.roll(g,-1,axis=1)-g)/hx
#        uxminustf=(3.0*g-4.0*tf.roll(g,1,axis=1)+1.0*tf.roll(g,2,axis=1))/(2.0*hx)
#        uxplustf=(-1.0*tf.roll(g,-2,axis=1)+4.0*tf.roll(g,-1,axis=1)-3.0*g)/(2.0*hx)                
#        uxminustf=(2.0*tf.roll(g,-1,axis=1)+3.0*g-6.0*tf.roll(g,1,axis=1)+1.0*tf.roll(g,2,axis=1))/(6.0*hx)
#        uxplustf=(-1.0*tf.roll(g,-2,axis=1)+6.0*tf.roll(g,-1,axis=1)-3.0*g-2.0*tf.roll(g,1,axis=1))/(6.0*hx)
#        advec=vplusextend*uxminustf+vminusextend*uxplustf
        return advec
    
    def advection2g(self,rho,none,none2,vextend):
        advec=vextend*(tf.roll(rho,1,axis=1)-tf.roll(rho,-1,axis=1))/(2*hx)
#        advec=vextend*(1/280*tf.roll(rho,4,axis=1)-4/105*tf.roll(rho,3,axis=1)+1/5*tf.roll(rho,2,axis=1)-4/5*tf.roll(rho,1,axis=1)+4/5*tf.roll(rho,-1,axis=1)-1/5*tf.roll(rho,-2,axis=1)+4/105*tf.roll(rho,-3,axis=1)-1/280*tf.roll(rho,-4,axis=1))/(hx)
#        rhox=(tf.roll(rho,-1,axis=1)-rho)/hx
#        advec=vextend*rhox
        return advec
    
    def advection2g2(self,rho,none,none2,vextend):
#        advec=vextend*(1/280*tf.roll(rho,4,axis=1)-4/105*tf.roll(rho,3,axis=1)+1/5*tf.roll(rho,2,axis=1)-4/5*tf.roll(rho,1,axis=1)+4/5*tf.roll(rho,-1,axis=1)-1/5*tf.roll(rho,-2,axis=1)+4/105*tf.roll(rho,-3,axis=1)-1/280*tf.roll(rho,-4,axis=1))/(hx)
#        rhox=(tf.roll(rho,-1,axis=1)-rho)/hx
        advec=vextend*(tf.roll(rho,1,axis=1)-tf.roll(rho,-1,axis=1))/(2*hx)
       # advec=vextend*rhox
        return advec
    
    
    def advection2(self,rho,vplusextend,vminusextend,vextend):
#        advec=vextend*(1/280*tf.roll(rho,4,axis=1)-4/105*tf.roll(rho,3,axis=1)+1/5*tf.roll(rho,2,axis=1)-4/5*tf.roll(rho,1,axis=1)+4/5*tf.roll(rho,-1,axis=1)-1/5*tf.roll(rho,-2,axis=1)+4/105*tf.roll(rho,-3,axis=1)-1/280*tf.roll(rho,-4,axis=1))/(hx)
        advec=vextend*(tf.roll(rho,1,axis=1)-tf.roll(rho,-1,axis=1))/(2*hx)
        #rhox=(rho-tf.roll(rho,1,axis=1))/hx#for rho equation
        #advec=vextend*rhox
#        uxminustf=(-1.0*tf.roll(rho,-2,axis=1)+4.0*tf.roll(rho,-1,axis=1)-3.0*rho)/(2.0*dx)
#        uxplustf=(3.0*rho-4.0*tf.roll(rho,1,axis=1)+1.0*tf.roll(rho,2,axis=1))/(2.0*dx)
#        uxplustf=(2.0*tf.roll(rho,-1,axis=1)+3.0*rho-6.0*tf.roll(rho,1,axis=1)+1.0*tf.roll(rho,2,axis=1))/(6.0*hx)
#        uxminustf=(-1.0*tf.roll(rho,-2,axis=1)+6.0*tf.roll(rho,-1,axis=1)-3.0*rho-2.0*tf.roll(rho,1,axis=1))/(6.0*hx)
#        advec=vplusextend*uxminustf+vminusextend*uxplustf
        return advec
    
    def projection(self,g,wvextend,ns):
        s=wvextend*g
        reduced=tf.math.reduce_sum(s/2.0,0)
        vv=tf.concat([reduced,reduced],0)
        for I in range(0,Nv-2):
            vv=tf.concat([vv,reduced],0)
        prj=tf.reshape(vv,[Nv,Nx,n_dat-ns-1])#wasn_dat-2
        return prj


    def net_uv(self,rho_extend,g,vextend,wvextend):

        ns=2
        wstiffg=self.wstiffg
        eps=(tf.math.tanh(wstiffg) + 1)*(max_epsilon-min_epsilon )/2+min_epsilon
                
        if Max_orders==0:
            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)

            temp=4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3]
            
        elif Max_orders==1:
            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            temp1=4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3]

            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            temp2=(4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3])/eps
            
            temp=temp1+temp2
        elif Max_orders==2:
            
            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            temp1=4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3]

            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            temp2=(4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3])/eps

            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,2)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,2)
            temp3=(4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3])/eps**2
            
            temp=temp1+temp2+temp3
        else:
            print('not implemented')#NOTE the IMEX-BDF-2 assumes g is stiff of order epsilon**2, but for the sake 
        if Max_orders==0:           #of demostrating that dictionarys should depend on epsilon, we assume
                                    # that the dictionary does not depend on epsilon.
            wstiffg2=self.wstiffg2
            u_g=g[:,:,2:n_dat-1]-4/3*g[:,:,1:n_dat-2]+1/3*g[:,:,0:n_dat-3]+dt*(temp)+2/3*dt*wstiffg2/(eps**0)*g[:,:,2:n_dat-1]
        elif Max_orders==1:   
            wstiffg2=self.wstiffg2
            u_g=g[:,:,2:n_dat-1]-4/3*g[:,:,1:n_dat-2]+1/3*g[:,:,0:n_dat-3]+dt*(temp)+2/3*dt*wstiffg2/(eps**1)*g[:,:,2:n_dat-1]
        elif Max_orders==2:   
            wstiffg2=self.wstiffg2
            u_g=g[:,:,2:n_dat-1]-4/3*g[:,:,1:n_dat-2]+1/3*g[:,:,0:n_dat-3]+dt*(temp)+2/3*dt*wstiffg2/(eps**2)*g[:,:,2:n_dat-1]
        else:
            print('not implemented')  
            
        u_rh=0*g

        ns=2
        Frhs_innerproduct=tf.math.reduce_sum(wvextend[:,:,0:n_dat-ns-1]*temp/2.0,0)
        return u_g,weights_g0,weights_g1,wstiffg,wstiffg2,Frhs_innerproduct,u_rh,eps    
    
    
    def callback(self, loss):
        print('Loss:', loss)
        
    def train(self, nIter):
        tf_dict = {self.g_tf: self.g,
                   self.rho_extend_tf: self.rho_extend,
                   self.vextend_tf: self.vextend,
                   self.wvextend_tf: self.wvextend}
        
        start_time = time.time()
        L=0
        for it in range(nIter):
            self.sess.run(self.train_op_Adam, tf_dict)
            # Print
            loss_value = self.sess.run(self.loss, tf_dict)
            Losss[L,0]=loss_value
            L=L+1
            if it % 10 == 0:
                elapsed = time.time() - start_time
                print('It: %d, Loss: %.3e, Time: %.2f' % 
                      (it, loss_value, elapsed))
                start_time = time.time()

#        self.optimizer.minimize(self.sess,
#                                feed_dict = tf_dict,
#                                fetches = [self.loss],
#                                loss_callback = self.callback)
            
    def predictrho(self,g):
        tf_dict = {self.g_tf: g,
                   self.rho_extend_tf: self.rho_extend,
                   self.vextend_tf: self.vextend,
                   self.wvextend_tf: self.wvextend}
        weights_g1=self.sess.run(self.weights_g1_tf)
        weights_g0=self.sess.run(self.weights_g0_tf)
        wstiff_g=self.sess.run(self.wstiff_g_tf)
        wstiff_g2=self.sess.run(self.wstiff_g2_tf)
#        gg=self.sess.run(self.g_pred)
        
        return weights_g0,weights_g1,wstiff_g,wstiff_g2
    
if __name__ == "__main__":
    
    TTdata = scipy.io.loadmat('data_mm.mat')
    
    x = TTdata['x']
    rho_Data = TTdata['u']
    gData = TTdata['g']
    v = TTdata['v']
    wv=TTdata['wv']
    dt=TTdata['dt']
    hx=TTdata['hx']

    flag=0
    if flag==1:
        Wdata0 = scipy.io.loadmat('W_bdf0.mat')
        weightsg0inp=Wdata0['weightsg0']

        Wdata1=scipy.io.loadmat('W_bdf1.mat')
        weightsg1inp=Wdata1['weightsg1']
        
        Wdata2=scipy.io.loadmat('W_bdf2.mat')
        weightsg2inp=Wdata2['weightsg2']

        Wdatas=scipy.io.loadmat('W_stiff_bdf')
        wstiffginp=Wdatas['wstiffg']
        
        Wdatas=scipy.io.loadmat('W_stiff_bdf2')
        wstiffginp=Wdatas['wstiffg2']
    else:
        weightsg0inp=0.0
        weightsg1inp=0.0
        weightsg2inp=0.0
        weightsrho0inp=0.0
        weightsrho1inp=0.0
        biasesg0inp=0.0
        biasesg1inp=0.0
        biasesrho0inp=0.0
        biasesrho1inp=0.0
        wstiffginp=0.0
        wstiffrhoinp=0.0
        wstiffginp2=0.0

            
    Nv,Nx,n=gData.shape
    
    xx=x    
    
    nskip=1
    n_start=round(0.5*n/3.0)
    n_end=round(2.75*n/3.0)
    n_dat_temp=n_end-n_start
    n_dat=round(n_dat_temp/nskip)
    T_final=n*dt
    dt=nskip*dt
    
    N_layers=2
    Max_orders=0
         
    choose_order=1
    
    if choose_order==1:
        g=np.zeros([Nv,Nx,n_dat], dtype=float)
        rho=np.zeros([Nx,n_dat], dtype=float)
        rho_extend=np.zeros([Nv,Nx,n_dat], dtype=float)
    else:
        g=np.zeros([Nv,Nx,n_dat], dtype=float)

    for K in range(0,n_dat):
        for I in range(0,Nv):
            for J in range(0,Nx):
                g[I,J,K]=gData[I,J,nskip*(K)+n_start]
    
    for K in range(0,n_dat):
        for J in range(0,Nx):
            rho[J,K]=rho_Data[J,nskip*(K)+n_start]
            
    wv=np.float32(wv)
    
    rho = np.float32(rho)

    vextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                vextend[I,J,K]=v[I,0]
                
    wvextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                wvextend[I,J,K]=wv[I,0]

    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                rho_extend[I,J,K]=rho[J,K]

    vextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                vextend[I,J,K]=v[I,0]
    
    xv=np.zeros([Nv,1],dtype=float)
    for I in range(0,Nv):
        xv[I,0]=-1.0+2.0/(Nv-1)*(I)
        
        
    v=np.float32(v)

    ns=2
 
    vplus=np.zeros([Nv,1],dtype=float)
    vminus=np.zeros([Nv,1],dtype=float)
    for j in range(0,Nv):
        if v[j]>0:            
            vplus[j,0]=v[j,0]
        else:
            vminus[j,0]=v[j,0]
    vplus=np.float32(vplus)
    vminus=np.float32(vminus)
    vplusextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    vminusextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                vplusextend[I,J,K]=vplus[I,0]
                vminusextend[I,J,K]=vminus[I,0]   
    
    N_s=3
    A1=np.zeros([N_s,N_s],dtype=float)
    c1=np.zeros([N_s,1],dtype=float)
    w1=np.zeros([N_s,1],dtype=float)

    A2=np.zeros([N_s,N_s],dtype=float)
    c2=np.zeros([N_s,1],dtype=float)
    w2=np.zeros([N_s,1],dtype=float)

    #IMEX RK ARS(2,2,2)
    gamma=1.0-np.sqrt(2.0)/2.0
    delta=1.0-1.0/(2.0*gamma)
    A1[1,0]=gamma
    A1[2,0]=delta
    A1[2,1]=1.0-delta
    w1[0,0]=delta
    w1[1,0]=1.0-delta
    w1[2,0]=0.0

    A2[1,1]=gamma
    A2[2,1]=1.0-gamma
    A2[2,2]=gamma
    w2[0,0]=0.0
    w2[1,0]=1.0-gamma
    w2[2,0]=gamma
    
    
    max_epsilon=1
    min_epsilon=0.000001
    
    Nsteps=80000
    Losss=np.zeros([Nsteps,1],dtype=float)
    Losss_domain=np.zeros([Nsteps,1],dtype=float)
    for I in range(0,Nsteps):
        Losss_domain[I,0]=I
    
    
    modelrho = PDE_CLASSIFY(rho_extend,g,n_dat,N_layers,Nx,dt,hx,v,vextend,vplus,vplusextend,vminus,vminusextend,wv,wvextend,A1,A2,w1,w2,flag,max_epsilon,min_epsilon,weightsg0inp,weightsg1inp,weightsg2inp,wstiffginp,wstiffginp2,Max_orders,Losss)

    start_time = time.time()
    modelrho.train(Nsteps)
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    weightsg0,weightsg1,wstiffg,wstiffg2= modelrho.predictrho(g)
    
    LLosss=np.zeros([Nsteps,1],dtype=float)
    for I in range(0,Nsteps):
        LLosss[I,0]=np.log(Losss[I,0])

    fig = plt.figure()
    plt.scatter(Losss_domain,LLosss, color='black', linewidth=2, label='Log of Loss vs Number of Iterations')
    plt.show()
    plt.legend()
    fig.savefig('LossBDF2_example1.png')
    
    savemat('Loss1.mat',{'L_domain':Losss_domain, 'Loss_y':LLosss})
    
    
    
    

    u_pred_ndat=np.zeros([Nx,1],dtype=float)

    eps=(np.tanh(wstiffg) + 1)*(max_epsilon-min_epsilon)/2+min_epsilon
    
    c_g,c_v_g_x,pvgx=coeffsg(weightsg0,N_layers,eps)
    c_rho,c_v_rho_x=coeffsrho(weightsg1,N_layers,eps)
    print('The learned G-equation is:')
    print(c_g+wstiffg2/eps**0,'g +',c_v_g_x,'v*g_x+',pvgx,'<vg_x>')
    print(c_rho,'rho +',c_v_rho_x,'v*rho_x+')
        
    

#    savemat('W_bdf0',{'weightsg0':weightsg0})
#    savemat('W_bdf1',{'weightsg1':weightsg1})
#    savemat('W_stiff_bdf',{'wstiffg':wstiffg})
#    savemat('W_stiff_bdf2',{'wstiffg2':wstiffg2})
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
#
# It: 0, Loss: 6.759e-02, Time: 0.75
# It: 10, Loss: 6.568e-02, Time: 0.19
# It: 20, Loss: 6.382e-02, Time: 0.18
# It: 30, Loss: 6.202e-02, Time: 0.17
# It: 40, Loss: 6.027e-02, Time: 0.18
# It: 50, Loss: 5.858e-02, Time: 0.18
# It: 60, Loss: 5.694e-02, Time: 0.17
# It: 70, Loss: 5.535e-02, Time: 0.17
# It: 80, Loss: 5.382e-02, Time: 0.17
# It: 90, Loss: 5.233e-02, Time: 0.17
# It: 100, Loss: 5.090e-02, Time: 0.17
# It: 110, Loss: 4.951e-02, Time: 0.17
# It: 120, Loss: 4.817e-02, Time: 0.17
# It: 130, Loss: 4.688e-02, Time: 0.18
# It: 140, Loss: 4.563e-02, Time: 0.17
# It: 150, Loss: 4.442e-02, Time: 0.17
# It: 160, Loss: 4.325e-02, Time: 0.17
# It: 170, Loss: 4.212e-02, Time: 0.17
# It: 180, Loss: 4.103e-02, Time: 0.16
# It: 190, Loss: 3.997e-02, Time: 0.17
# It: 200, Loss: 3.895e-02, Time: 0.17
# ...

# %% [markdown]
# As seen by the output, the right-hand-sdie of g-equation is:
# -78.78022003173828 g + -2.394277 v*g_x+ 37.348785 <vg_x>
# 0.0 rho + -118.38119 v*rho_x+...
# wheareas the correct equation should be:
# g_t= - (65536)g - 256v*g_x - 256<vg_x> - (65536)v*rho_x
# To improve the result, we change the parameter Max_orders=2. That is, we assume that
# the dictionary now contains terms of orders O(1), O(epsilon), and O(epsilon^2).

# %%
#This is for 2nd order IMEX-BDF-2 fitting.
#This scheme uses two layers
#The advection and projection operations are used to generate
#Terms for the dictionary.
#The parameter Max_order=0 means the scheme does not depend on
#epsilon and thus the epsilon output should be ignored

import sys
sys.path.insert(0, '../../Utilities/')
import scipy.io
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.io import savemat
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show
from scipy import interpolate




def coeffsrho(W2,N_layers,eps):
    if Max_orders==0:
        c_rho=0.0
        c_v_rho_x=W2[2][0,0]
    elif Max_orders==1:
        c_rho=0.0
        c_v_rho_x=W2[2][0,0]+W2[2][1,0]/eps
    elif Max_orders==2:
        c_rho=0.0
        c_v_rho_x=W2[2][0,0]+W2[2][1,0]/eps+W2[2][2,0]/eps**2
    else:
        print('not implemented')
    return c_rho,c_v_rho_x

def coeffsg(W2,N_layers,eps):
    if Max_orders==0:
        c_g=0.0
        c_v_g_x=W2[2][0,0]
        pvgx=W2[2][0,3]*W2[0][0,0]
        pvgx=pvgx+W2[2][0,5]*W2[1][0,0]
        pvgx=pvgx+W2[2][0,5]*W2[1][0,3]*W2[0][0,0]
    elif Max_orders==1:
        c_g=0.0
        c_v_g_x=W2[2][0,0]+W2[2][1,0]/eps
        pvgx=W2[2][0,3]*W2[0][0,0]+W2[2][1,3]*W2[0][1,0]/eps
        pvgx=pvgx+W2[2][0,5]*W2[1][0,0]+W2[2][1,5]*W2[1][1,0]/eps
        pvgx=pvgx+W2[2][0,5]*W2[1][0,3]*W2[0][0,0]+W2[2][1,5]*W2[1][1,3]*W2[0][1,0]/eps
    elif Max_orders==2:
        c_g=0.0
        c_v_g_x=W2[2][0,0]+W2[2][1,0]/eps+W2[2][2,0]/eps**2
        pvgx=W2[2][0,3]*W2[0][0,0]+W2[2][1,3]*W2[0][1,0]/eps+W2[2][2,3]*W2[0][2,0]/eps**2
        pvgx=pvgx+W2[2][0,5]*W2[1][0,0]+W2[2][1,5]*W2[1][1,0]/eps+W2[2][2,5]*W2[1][2,0]/eps**2
        pvgx=pvgx+W2[2][0,5]*W2[1][0,3]*W2[0][0,0]+W2[2][1,5]*W2[1][1,3]*W2[0][1,0]/eps+W2[2][2,5]*W2[1][2,3]*W2[0][2,0]/eps**2
    else:
        print('Not implemented')
    return c_g,c_v_g_x,pvgx


class PDE_CLASSIFY:
    def __init__(self,rho_extend,g,n_dat,N_layers,Nx,dt,hx,v,vextend,vplus,vplusextend,vminus,vminusextend,wv,wvextend,A1,A2,w1,w2,flag,max_epsilon,min_epsilon,weightsg0inp,weightsg1inp,weightsg2inp,wstiffginp,wstiffginp2,Max_orders,Losss):
        self.rho_extend = rho_extend
        self.vextend = vextend
        self.wvextend = wvextend
        self.g = g
        self.wv = wv
        self.Losss=Losss
        self.v=v
        self.vplus=vplus
        self.vminus=vminus
        self.vplusextend=vplusextend
        self.vminusextend=vminusextend
        self.weightsg0inp=weightsg0inp
        self.weightsg1inp=weightsg1inp
        self.weightsg2inp=weightsg2inp
        self.wstiffginp=wstiffginp
        self.wstiffginp2=wstiffginp2
        self.max_epsilon=max_epsilon
        self.min_epsilon=min_epsilon
        self.Max_orders=Max_orders
        
        self.A1=A1
        self.A2=A2
        self.w1=w1
        self.w2=w2

        self.Nx=Nx
        self.dt=dt
        self.N_layers=N_layers
        self.n_dat=n_dat
        self.hx=hx

        self.weights_g0,self.weights_g1,self.wstiffg, self.wstiffg2= self.initialize_NNg(N_layers)
        
        self.v_tf = tf.placeholder(tf.float32, shape=[None, self.v.shape[1]])
        self.rho_extend_tf = tf.placeholder(tf.float32, shape=[None, None, self.rho_extend.shape[2]])

        self.g_tf = tf.placeholder(tf.float32, shape=[None, None, self.g.shape[2]])

        self.vextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.vextend.shape[2]])
        self.vplusextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.vplusextend.shape[2]])
        self.vminusextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.vminusextend.shape[2]])
        self.wvextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.wvextend.shape[2]])
        
        # tf Graphs
        self.g_pred,self.weights_g0_tf, self.weights_g1_tf,self.wstiff_g_tf,self.wstiff_g2_tf,self.g_innerproduct,self.rho_pred,self.eps_pred = self.net_uv(self.rho_extend_tf,self.g_tf,self.vextend_tf,self.wvextend_tf)
        # Loss

        self.loss = tf.reduce_mean(tf.abs(self.g_pred))

    # Optimizers
        self.optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
    name='Adam')   
    
        self.optimizer_Adam = tf.train.AdamOptimizer()
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss)
                
        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        init = tf.global_variables_initializer()
        self.sess.run(init)


    def initialize_NNg(self, N_layers):
        if Max_orders==0:
            weights_g0=[]
            weights_g1=[]
            initializeit=1.5
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([1,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g0.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([1,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g0.append(W_last_g)
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([1,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g1.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([1,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g1.append(W_last_g)
        elif Max_orders==1:
            weights_g0=[]
            weights_g1=[]
            initializeit=1.5
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([2,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g0.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([2,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g0.append(W_last_g)
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([2,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g1.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([2,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g1.append(W_last_g)
        elif Max_orders==2:
            weights_g0=[]
            weights_g1=[]
            initializeit=1.5
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([3,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g0.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([3,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g0.append(W_last_g)
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([3,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g1.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([3,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g1.append(W_last_g)
        else:
            print('Not implemented')
 
        wstiffg=1*tf.Variable(1.0,dtype=tf.float32)

        wstiffg2=1*tf.Variable(1.0,dtype=tf.float32)

        return weights_g0,weights_g1,wstiffg,wstiffg2




    def neural_netg(self,g,weights_g0,eps,wstiffg,v,n_dat,N_layers,Nx,dt,ns,po):
##############################################################################
#                                                                            #
#    #####       ######                            #                         #
#    #           #                                 #                         #
#    #   ###     ######   #####   #   #   ####   #####  #   #####  #####     #
#    #    #      #       #    #   #   #  #   #     #    #   #   #  #   #     #
#    #####       ######   #####   #####   #####    #    #   #####  #   #     #
#                             #                                              #
#                             ##                                             #
#                             #                                              #
##############################################################################             
            
        if (N_layers==0):
            WL=weights_g0[0]
            temp1=self.advection2g(g,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp2=self.projection(g,wvextend[:,:,0:n_dat-ns-1],ns)
            F_rhs_g=WL[po,0]*temp1+WL[po,1]*temp2
        elif (N_layers==1):
            W0=weights_g0[0]
            temp1=self.advection2g(g,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp2=self.projection(g,wvextend[:,:,0:n_dat-ns-1],ns)
            h1=W0[po,0]*temp1+W0[po,1]*temp2
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp12=self.projection(h1,wvextend[:,:,0:n_dat-ns-1],ns)
            WL=weights_g0[1]
            F_rhs_g=WL[po,0]*temp1+WL[po,1]*temp2+WL[po,2]*temp11+WL[po,3]*temp12
        elif N_layers==2:
            ns=1
            W0=weights_g0[0]
            temp1=self.advection2g(g,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp2=self.projection(g,wvextend[:,:,0:n_dat-ns-1],ns)
            h1=W0[po,0]*temp1+W0[po,1]*temp2
            W1=weights_g0[1]
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp12=self.projection(h1,wvextend[:,:,0:n_dat-ns-1],ns)
            h2=W1[po,0]*temp1+W1[po,1]*temp2+W1[po,2]*temp11+W1[po,3]*temp12
            temp111=self.advection2g(h2,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp112=self.projection(h2,wvextend[:,:,0:n_dat-ns-1],ns)
            WL=weights_g0[2]
            F_rhs_g=(WL[po,0])*temp1+(WL[po,1])*temp2+(WL[po,2])*temp11+(WL[po,3])*temp12+(WL[po,4])*temp111+(WL[po,5])*temp112
        else:
            print('Not implemented')

        return F_rhs_g, weights_g0, v
    
    def neural_netrho(self,rho_extend,weights_g1,eps,wstiffg,v,n_dat,N_layers,Nx,dt,ns,po):
##################################################################################   
#                                                                                #
#        #              ######                            #                      #
#        #              #                                 #                      #
#  ##### #####  #####   ######   #####   #   #   ####   #####  #   #####  #####  #
#  #     #   #  #   #   #       #    #   #   #  #   #     #    #   #   #  #   #  #
#  #     #   #  #####   ######   #####   #####   #####    #    #   #####  #   #  #
#                                    #                                           #
#                                    ##                                          #
#                                    #                                           #
##################################################################################        
        if N_layers==0:
            WL=weights_g1[0]
            temp1=self.advection2g(rho_extend,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            F_rhs_rho=WL[po,0]*temp1#
        elif N_layers==1:
            W0=weights_g1[0]
            temp1=self.advection2g(rho_extend,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            h1=W0[po,0]*temp1
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            WL=weights_g1[1]
            F_rhs_rho=WL[po,0]*temp1+WL[po,2]*temp11
        elif N_layers==2:
            ns=1
            W0=weights_g1[0]
            temp1=self.advection2g(rho_extend,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            h1=W0[po,0]*temp1
            W1=weights_g1[1]
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            h2=W1[po,0]*temp1+W1[po,2]*temp11
            temp111=self.advection2g(h2,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            WL=weights_g1[2]
            F_rhs_rho=(WL[po,0])*temp1+(WL[po,2])*temp11+(WL[po,4])*temp111
        else:
            print('Not implemented')
        return F_rhs_rho, weights_g1
     
    def firstderiv(self,g):
        out=(tf.roll(g,1,axis=1)-tf.roll(g,-1,axis=1))/(2.0*hx)
        return out
    
    def secondderiv(self,g):
        out=(tf.roll(g,1,axis=1)-2.0*g+tf.roll(g,-1,axis=1))/(hx*hx)
        return out
        
    def rhoOP(self,rhoextend,g):
        rhog=rhoextend*g
        return rhog
    
    def gOP(self,g,f):
        gf=g*f
        return gf
    
    def advection(self,g,vplusextend,vminusextend,vextend):
        advec=vextend*(tf.roll(g,1,axis=1)-tf.roll(g,-1,axis=1))/(2*hx)
        #        uxminustf=(g-tf.roll(g,1,axis=1))/hx
#        uxplustf=(tf.roll(g,-1,axis=1)-g)/hx
#        uxminustf=(3.0*g-4.0*tf.roll(g,1,axis=1)+1.0*tf.roll(g,2,axis=1))/(2.0*hx)
#        uxplustf=(-1.0*tf.roll(g,-2,axis=1)+4.0*tf.roll(g,-1,axis=1)-3.0*g)/(2.0*hx)                
#        uxminustf=(2.0*tf.roll(g,-1,axis=1)+3.0*g-6.0*tf.roll(g,1,axis=1)+1.0*tf.roll(g,2,axis=1))/(6.0*hx)
#        uxplustf=(-1.0*tf.roll(g,-2,axis=1)+6.0*tf.roll(g,-1,axis=1)-3.0*g-2.0*tf.roll(g,1,axis=1))/(6.0*hx)
#        advec=vplusextend*uxminustf+vminusextend*uxplustf
        return advec
    
    def advection2g(self,rho,none,none2,vextend):
        advec=vextend*(tf.roll(rho,1,axis=1)-tf.roll(rho,-1,axis=1))/(2*hx)
#        advec=vextend*(1/280*tf.roll(rho,4,axis=1)-4/105*tf.roll(rho,3,axis=1)+1/5*tf.roll(rho,2,axis=1)-4/5*tf.roll(rho,1,axis=1)+4/5*tf.roll(rho,-1,axis=1)-1/5*tf.roll(rho,-2,axis=1)+4/105*tf.roll(rho,-3,axis=1)-1/280*tf.roll(rho,-4,axis=1))/(hx)
#        rhox=(tf.roll(rho,-1,axis=1)-rho)/hx
#        advec=vextend*rhox
        return advec
    
    def advection2g2(self,rho,none,none2,vextend):
#        advec=vextend*(1/280*tf.roll(rho,4,axis=1)-4/105*tf.roll(rho,3,axis=1)+1/5*tf.roll(rho,2,axis=1)-4/5*tf.roll(rho,1,axis=1)+4/5*tf.roll(rho,-1,axis=1)-1/5*tf.roll(rho,-2,axis=1)+4/105*tf.roll(rho,-3,axis=1)-1/280*tf.roll(rho,-4,axis=1))/(hx)
#        rhox=(tf.roll(rho,-1,axis=1)-rho)/hx
        advec=vextend*(tf.roll(rho,1,axis=1)-tf.roll(rho,-1,axis=1))/(2*hx)
       # advec=vextend*rhox
        return advec
    
    
    def advection2(self,rho,vplusextend,vminusextend,vextend):
#        advec=vextend*(1/280*tf.roll(rho,4,axis=1)-4/105*tf.roll(rho,3,axis=1)+1/5*tf.roll(rho,2,axis=1)-4/5*tf.roll(rho,1,axis=1)+4/5*tf.roll(rho,-1,axis=1)-1/5*tf.roll(rho,-2,axis=1)+4/105*tf.roll(rho,-3,axis=1)-1/280*tf.roll(rho,-4,axis=1))/(hx)
        advec=vextend*(tf.roll(rho,1,axis=1)-tf.roll(rho,-1,axis=1))/(2*hx)
        #rhox=(rho-tf.roll(rho,1,axis=1))/hx#for rho equation
        #advec=vextend*rhox
#        uxminustf=(-1.0*tf.roll(rho,-2,axis=1)+4.0*tf.roll(rho,-1,axis=1)-3.0*rho)/(2.0*dx)
#        uxplustf=(3.0*rho-4.0*tf.roll(rho,1,axis=1)+1.0*tf.roll(rho,2,axis=1))/(2.0*dx)
#        uxplustf=(2.0*tf.roll(rho,-1,axis=1)+3.0*rho-6.0*tf.roll(rho,1,axis=1)+1.0*tf.roll(rho,2,axis=1))/(6.0*hx)
#        uxminustf=(-1.0*tf.roll(rho,-2,axis=1)+6.0*tf.roll(rho,-1,axis=1)-3.0*rho-2.0*tf.roll(rho,1,axis=1))/(6.0*hx)
#        advec=vplusextend*uxminustf+vminusextend*uxplustf
        return advec
    
    def projection(self,g,wvextend,ns):
        s=wvextend*g
        reduced=tf.math.reduce_sum(s/2.0,0)
        vv=tf.concat([reduced,reduced],0)
        for I in range(0,Nv-2):
            vv=tf.concat([vv,reduced],0)
        prj=tf.reshape(vv,[Nv,Nx,n_dat-ns-1])#wasn_dat-2
        return prj


    def net_uv(self,rho_extend,g,vextend,wvextend):

        ns=2
        wstiffg=self.wstiffg
        eps=(tf.math.tanh(wstiffg) + 1)*(max_epsilon-min_epsilon )/2+min_epsilon
        wstiffg2=self.wstiffg2
        
        if Max_orders==0:
            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)

            temp=4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3]
            
        elif Max_orders==1:
            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            temp1=4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3]

            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            temp2=(4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3])/eps
            
            temp=temp1+temp2
        elif Max_orders==2:
            
            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            temp1=4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3]

            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            temp2=(4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3])/eps

            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,2)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,2)
            temp3=(4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3])/eps**2
            
            temp=temp1+temp2+temp3
        else:
            print('not yet implemented')
            
        u_g=g[:,:,2:n_dat-1]-4/3*g[:,:,1:n_dat-2]+1/3*g[:,:,0:n_dat-3]+dt*(temp)+2/3*dt*wstiffg2/(eps**2)*g[:,:,2:n_dat-1]

        u_rh=0*g

        ns=2
        Frhs_innerproduct=tf.math.reduce_sum(wvextend[:,:,0:n_dat-ns-1]*temp/2.0,0)
        
        return u_g,weights_g0,weights_g1,wstiffg,wstiffg2,Frhs_innerproduct,u_rh,eps    
    
    
    def callback(self, loss):
        print('Loss:', loss)
        
    def train(self, nIter):
        tf_dict = {self.g_tf: self.g,
                   self.rho_extend_tf: self.rho_extend,
                   self.vextend_tf: self.vextend,
                   self.wvextend_tf: self.wvextend}
        
        start_time = time.time()
        L=0
        for it in range(nIter):
            self.sess.run(self.train_op_Adam, tf_dict)
            # Print
            loss_value = self.sess.run(self.loss, tf_dict)
            Losss[L,0]=loss_value
            L=L+1
            if it % 10 == 0:
                elapsed = time.time() - start_time
                print('It: %d, Loss: %.3e, Time: %.2f' % 
                      (it, loss_value, elapsed))
                start_time = time.time()

#        self.optimizer.minimize(self.sess,
#                                feed_dict = tf_dict,
#                                fetches = [self.loss],
#                                loss_callback = self.callback)
            
    def predictrho(self,g):
        tf_dict = {self.g_tf: g,
                   self.rho_extend_tf: self.rho_extend,
                   self.vextend_tf: self.vextend,
                   self.wvextend_tf: self.wvextend}
        weights_g1=self.sess.run(self.weights_g1_tf)
        weights_g0=self.sess.run(self.weights_g0_tf)
        wstiff_g=self.sess.run(self.wstiff_g_tf)
        wstiff_g2=self.sess.run(self.wstiff_g2_tf)        
        return weights_g0,weights_g1,wstiff_g,wstiff_g2
    
if __name__ == "__main__":
    
    TTdata = scipy.io.loadmat('data_mm.mat')
    
    x = TTdata['x']
    rho_Data = TTdata['u']
    gData = TTdata['g']
    v = TTdata['v']
    wv=TTdata['wv']
    dt=TTdata['dt']
    hx=TTdata['hx']

    flag=0
    if flag==1:
        Wdata0 = scipy.io.loadmat('W_bdf0.mat')
        weightsg0inp=Wdata0['weightsg0']

        Wdata1=scipy.io.loadmat('W_bdf1.mat')
        weightsg1inp=Wdata1['weightsg1']
        
        Wdata2=scipy.io.loadmat('W_bdf2.mat')
        weightsg2inp=Wdata2['weightsg2']

        Wdatas=scipy.io.loadmat('W_stiff_bdf')
        wstiffginp=Wdatas['wstiffg']
        
        Wdatas=scipy.io.loadmat('W_stiff_bdf2')
        wstiffginp=Wdatas['wstiffg2']
    else:
        weightsg0inp=0.0
        weightsg1inp=0.0
        weightsg2inp=0.0
        weightsrho0inp=0.0
        weightsrho1inp=0.0
        biasesg0inp=0.0
        biasesg1inp=0.0
        biasesrho0inp=0.0
        biasesrho1inp=0.0
        wstiffginp=0.0
        wstiffrhoinp=0.0
        wstiffginp2=0.0

            
    Nv,Nx,n=gData.shape
    
    xx=x    
    
    nskip=1
    n_start=round(0.5*n/3.0)
    n_end=round(2.75*n/3.0)
    n_dat_temp=n_end-n_start
    n_dat=round(n_dat_temp/nskip)
    T_final=n*dt
    dt=nskip*dt
    
    N_layers=2
    Max_orders=2
         
    choose_order=1
    
    if choose_order==1:
        g=np.zeros([Nv,Nx,n_dat], dtype=float)
        rho=np.zeros([Nx,n_dat], dtype=float)
        rho_extend=np.zeros([Nv,Nx,n_dat], dtype=float)
    else:
        g=np.zeros([Nv,Nx,n_dat], dtype=float)

    for K in range(0,n_dat):
        for I in range(0,Nv):
            for J in range(0,Nx):
                g[I,J,K]=gData[I,J,nskip*(K)+n_start]
    
    for K in range(0,n_dat):
        for J in range(0,Nx):
            rho[J,K]=rho_Data[J,nskip*(K)+n_start]
            
    wv=np.float32(wv)
    
    rho = np.float32(rho)

    vextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                vextend[I,J,K]=v[I,0]
                
    wvextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                wvextend[I,J,K]=wv[I,0]

    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                rho_extend[I,J,K]=rho[J,K]

    vextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                vextend[I,J,K]=v[I,0]
    
    xv=np.zeros([Nv,1],dtype=float)
    for I in range(0,Nv):
        xv[I,0]=-1.0+2.0/(Nv-1)*(I)
        
        
    v=np.float32(v)

    ns=2
 
    vplus=np.zeros([Nv,1],dtype=float)
    vminus=np.zeros([Nv,1],dtype=float)
    for j in range(0,Nv):
        if v[j]>0:            
            vplus[j,0]=v[j,0]
        else:
            vminus[j,0]=v[j,0]
    vplus=np.float32(vplus)
    vminus=np.float32(vminus)
    vplusextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    vminusextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                vplusextend[I,J,K]=vplus[I,0]
                vminusextend[I,J,K]=vminus[I,0]   
    
    N_s=3
    A1=np.zeros([N_s,N_s],dtype=float)
    c1=np.zeros([N_s,1],dtype=float)
    w1=np.zeros([N_s,1],dtype=float)

    A2=np.zeros([N_s,N_s],dtype=float)
    c2=np.zeros([N_s,1],dtype=float)
    w2=np.zeros([N_s,1],dtype=float)

    #IMEX RK ARS(2,2,2)
    gamma=1.0-np.sqrt(2.0)/2.0
    delta=1.0-1.0/(2.0*gamma)
    A1[1,0]=gamma
    A1[2,0]=delta
    A1[2,1]=1.0-delta
    w1[0,0]=delta
    w1[1,0]=1.0-delta
    w1[2,0]=0.0

    A2[1,1]=gamma
    A2[2,1]=1.0-gamma
    A2[2,2]=gamma
    w2[0,0]=0.0
    w2[1,0]=1.0-gamma
    w2[2,0]=gamma
    
    
    max_epsilon=0.1
    min_epsilon=0.001
    
    Nsteps=80000
    Losss=np.zeros([Nsteps,1],dtype=float)
    Losss_domain=np.zeros([Nsteps,1],dtype=float)
    for I in range(0,Nsteps):
        Losss_domain[I,0]=I
    
    
    modelrho = PDE_CLASSIFY(rho_extend,g,n_dat,N_layers,Nx,dt,hx,v,vextend,vplus,vplusextend,vminus,vminusextend,wv,wvextend,A1,A2,w1,w2,flag,max_epsilon,min_epsilon,weightsg0inp,weightsg1inp,weightsg2inp,wstiffginp,wstiffginp2,Max_orders,Losss)

    start_time = time.time()
    modelrho.train(Nsteps)
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    weightsg0,weightsg1,wstiffg,wstiffg2= modelrho.predictrho(g)
    
    LLosss=np.zeros([Nsteps,1],dtype=float)
    for I in range(0,Nsteps):
        LLosss[I,0]=np.log(Losss[I,0])

    fig = plt.figure()
    plt.scatter(Losss_domain,LLosss, color='black', linewidth=2, label='Log of Loss vs Number of Iterations')
    plt.show()
    plt.legend()
    fig.savefig('LossBDF2_example1.png')
    
    savemat('Loss2.mat',{'L_domain':Losss_domain, 'Loss_y':LLosss})
    
    
    
    

    u_pred_ndat=np.zeros([Nx,1],dtype=float)

    eps=(np.tanh(wstiffg) + 1)*(max_epsilon-min_epsilon)/2+min_epsilon
    
    c_g,c_v_g_x,pvgx=coeffsg(weightsg0,N_layers,eps)
    c_rho,c_v_rho_x=coeffsrho(weightsg1,N_layers,eps)
    print('The learned G-equation is:')
    print(c_g+wstiffg2/eps**2,'g +',c_v_g_x,'v*g_x+',pvgx,'<vg_x>')
    print(c_rho,'rho +',c_v_rho_x,'v*rho_x+')
        
    

#    savemat('W_bdf0',{'weightsg0':weightsg0})
#    savemat('W_bdf1',{'weightsg1':weightsg1})
#    savemat('W_stiff_bdf',{'wstiffg':wstiffg})
#    savemat('W_stiff_bdf2',{'wstiffg2':wstiffg2})
# Out:
# WARNING:tensorflow:From C:\Users\Ricardo\miniconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
#
# It: 0, Loss: 9.286e+00, Time: 1.83
# It: 10, Loss: 8.969e+00, Time: 0.38
# It: 20, Loss: 8.662e+00, Time: 0.37
# It: 30, Loss: 8.367e+00, Time: 0.39
# It: 40, Loss: 8.083e+00, Time: 0.37
# It: 50, Loss: 7.810e+00, Time: 0.38
# It: 60, Loss: 7.547e+00, Time: 0.39
# It: 70, Loss: 7.295e+00, Time: 0.38
# It: 80, Loss: 7.053e+00, Time: 0.40
# It: 90, Loss: 6.821e+00, Time: 0.38
# It: 100, Loss: 6.597e+00, Time: 0.39
# It: 110, Loss: 6.381e+00, Time: 0.38
# ...

# %% [markdown]
# Here we see that the produced RHS of the PDE is:
# 62384.73056542609 g + -258.39823488376555 v*g_x+ 235.71030679613065 <vg_x>
# 0.0 rho + -62446.05028140223 v*rho_x+...
# In other words:
# (65536-3151.26)g - (256 + 2.39)v*g_x + (256 -20.28)<vg_x>-(65536-3089.94) v*rho_x+...
# This is much better than the previous result.

# %%
#This is for 2nd order IMEX-BDF-2 fitting.
#This scheme uses two layers
#The advection and projection operations are used to generate
#Terms for the dictionary.
#The parameter Max_order=0 means the scheme does not depend on
#epsilon and thus the epsilon output should be ignored

import sys
sys.path.insert(0, '../../Utilities/')
import scipy.io
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.io import savemat
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show
from scipy import interpolate




def coeffsrho(W2,N_layers,eps):
    if Max_orders==0:
        c_rho=0.0
        c_v_rho_x=W2[2][0,0]
    elif Max_orders==1:
        c_rho=0.0
        c_v_rho_x=W2[2][0,0]+W2[2][1,0]/eps
    elif Max_orders==2:
        c_rho=0.0
        c_v_rho_x=W2[2][0,0]+W2[2][1,0]/eps+W2[2][2,0]/eps**2
    else:
        print('not implemented')
    return c_rho,c_v_rho_x

def coeffsg(W2,N_layers,eps):
    if Max_orders==0:
        c_g=0.0
        c_v_g_x=W2[2][0,0]
        pvgx=W2[2][0,3]*W2[0][0,0]
        pvgx=pvgx+W2[2][0,5]*W2[1][0,0]
        pvgx=pvgx+W2[2][0,5]*W2[1][0,3]*W2[0][0,0]
    elif Max_orders==1:
        c_g=0.0
        c_v_g_x=W2[2][0,0]+W2[2][1,0]/eps
        pvgx=W2[2][0,3]*W2[0][0,0]+W2[2][1,3]*W2[0][1,0]/eps
        pvgx=pvgx+W2[2][0,5]*W2[1][0,0]+W2[2][1,5]*W2[1][1,0]/eps
        pvgx=pvgx+W2[2][0,5]*W2[1][0,3]*W2[0][0,0]+W2[2][1,5]*W2[1][1,3]*W2[0][1,0]/eps
    elif Max_orders==2:
        c_g=0.0
        c_v_g_x=W2[2][0,0]+W2[2][1,0]/eps+W2[2][2,0]/eps**2
        pvgx=W2[2][0,3]*W2[0][0,0]+W2[2][1,3]*W2[0][1,0]/eps+W2[2][2,3]*W2[0][2,0]/eps**2
        pvgx=pvgx+W2[2][0,5]*W2[1][0,0]+W2[2][1,5]*W2[1][1,0]/eps+W2[2][2,5]*W2[1][2,0]/eps**2
        pvgx=pvgx+W2[2][0,5]*W2[1][0,3]*W2[0][0,0]+W2[2][1,5]*W2[1][1,3]*W2[0][1,0]/eps+W2[2][2,5]*W2[1][2,3]*W2[0][2,0]/eps**2
    else:
        print('Not implemented')
    return c_g,c_v_g_x,pvgx


class PDE_CLASSIFY:
    def __init__(self,rho_extend,g,n_dat,N_layers,Nx,dt,hx,v,vextend,vplus,vplusextend,vminus,vminusextend,wv,wvextend,A1,A2,w1,w2,flag,max_epsilon,min_epsilon,weightsg0inp,weightsg1inp,weightsg2inp,wstiffginp,wstiffginp2,Max_orders,Losss):
        self.rho_extend = rho_extend
        self.vextend = vextend
        self.wvextend = wvextend
        self.g = g
        self.wv = wv
        self.Losss=Losss
        self.v=v
        self.vplus=vplus
        self.vminus=vminus
        self.vplusextend=vplusextend
        self.vminusextend=vminusextend
        self.weightsg0inp=weightsg0inp
        self.weightsg1inp=weightsg1inp
        self.weightsg2inp=weightsg2inp
        self.wstiffginp=wstiffginp
        self.wstiffginp2=wstiffginp2
        self.max_epsilon=max_epsilon
        self.min_epsilon=min_epsilon
        self.Max_orders=Max_orders
        
        self.A1=A1
        self.A2=A2
        self.w1=w1
        self.w2=w2

        self.Nx=Nx
        self.dt=dt
        self.N_layers=N_layers
        self.n_dat=n_dat
        self.hx=hx

        self.weights_g0,self.weights_g1,self.wstiffg, self.wstiffg2= self.initialize_NNg(N_layers)
        
        self.v_tf = tf.placeholder(tf.float32, shape=[None, self.v.shape[1]])
        self.rho_extend_tf = tf.placeholder(tf.float32, shape=[None, None, self.rho_extend.shape[2]])

        self.g_tf = tf.placeholder(tf.float32, shape=[None, None, self.g.shape[2]])

        self.vextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.vextend.shape[2]])
        self.vplusextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.vplusextend.shape[2]])
        self.vminusextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.vminusextend.shape[2]])
        self.wvextend_tf = tf.placeholder(tf.float32, shape=[None, None, self.wvextend.shape[2]])
        
        # tf Graphs
        self.g_pred,self.weights_g0_tf, self.weights_g1_tf,self.wstiff_g_tf,self.wstiff_g2_tf,self.g_innerproduct,self.rho_pred,self.eps_pred = self.net_uv(self.rho_extend_tf,self.g_tf,self.vextend_tf,self.wvextend_tf)
        # Loss

        gamma=0.000001
        self.loss = tf.reduce_mean(tf.abs(self.g_pred))+gamma*(tf.reduce_mean(tf.abs(self.weights_g0_tf[0]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[1]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[2]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[0]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[1]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[2])))#+tf.reduce0_tf[3]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[4]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[5]))+tf.reduce_mean(tf.abs(self.weights_g0_tf[6])))+gamma*(tf.reduce_mean(tf.abs(self.weights_g1_tf[0]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[1]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[2]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[3]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[4]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[5]))+tf.reduce_mean(tf.abs(self.weights_g1_tf[6])))#+tf.reduce_mean(tf.square(self.g_innerproduct))#+tf.reduce_mean(dt*tf.abs(self.g_innerproduct))

    # Optimizers
        self.optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
    name='Adam')   
    
        self.optimizer_Adam = tf.train.AdamOptimizer()
        self.train_op_Adam = self.optimizer_Adam.minimize(self.loss)
                
        # tf session
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        init = tf.global_variables_initializer()
        self.sess.run(init)


    def initialize_NNg(self, N_layers):
        if Max_orders==0:
            weights_g0=[]
            weights_g1=[]
            initializeit=1.5
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([1,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g0.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([1,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g0.append(W_last_g)
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([1,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g1.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([1,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g1.append(W_last_g)
        elif Max_orders==1:
            weights_g0=[]
            weights_g1=[]
            initializeit=1.5
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([2,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g0.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([2,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g0.append(W_last_g)
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([2,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g1.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([2,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g1.append(W_last_g)
        elif Max_orders==2:
            weights_g0=[]
            weights_g1=[]
            initializeit=1.5
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([3,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g0.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([3,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g0.append(W_last_g)
            for I in range(0,N_layers):
                W=initializeit*tf.Variable(tf.ones([3,2+2*I],dtype=tf.float32),dtype=tf.float32)
                weights_g1.append(W)
            W_last_g=initializeit*tf.Variable(tf.ones([3,2+2*N_layers], dtype=tf.float32), dtype=tf.float32)
            weights_g1.append(W_last_g)
        else:
            print('Not implemented')
 
        wstiffg=1*tf.Variable(1.0,dtype=tf.float32)

        wstiffg2=1*tf.Variable(1.0,dtype=tf.float32)

        return weights_g0,weights_g1,wstiffg,wstiffg2




    def neural_netg(self,g,weights_g0,eps,wstiffg,v,n_dat,N_layers,Nx,dt,ns,po):
##############################################################################
#                                                                            #
#    #####       ######                            #                         #
#    #           #                                 #                         #
#    #   ###     ######   #####   #   #   ####   #####  #   #####  #####     #
#    #    #      #       #    #   #   #  #   #     #    #   #   #  #   #     #
#    #####       ######   #####   #####   #####    #    #   #####  #   #     #
#                             #                                              #
#                             ##                                             #
#                             #                                              #
##############################################################################             
            
        if (N_layers==0):
            WL=weights_g0[0]
            temp1=self.advection2g(g,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp2=self.projection(g,wvextend[:,:,0:n_dat-ns-1],ns)
            F_rhs_g=WL[po,0]*temp1+WL[po,1]*temp2
        elif (N_layers==1):
            W0=weights_g0[0]
            temp1=self.advection2g(g,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp2=self.projection(g,wvextend[:,:,0:n_dat-ns-1],ns)
            h1=W0[po,0]*temp1+W0[po,1]*temp2
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp12=self.projection(h1,wvextend[:,:,0:n_dat-ns-1],ns)
            WL=weights_g0[1]
            F_rhs_g=WL[po,0]*temp1+WL[po,1]*temp2+WL[po,2]*temp11+WL[po,3]*temp12
        elif N_layers==2:
            ns=1
            W0=weights_g0[0]
            temp1=self.advection2g(g,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp2=self.projection(g,wvextend[:,:,0:n_dat-ns-1],ns)
            h1=W0[po,0]*temp1+W0[po,1]*temp2
            W1=weights_g0[1]
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp12=self.projection(h1,wvextend[:,:,0:n_dat-ns-1],ns)
            h2=W1[po,0]*temp1+W1[po,1]*temp2+W1[po,2]*temp11+W1[po,3]*temp12
            temp111=self.advection2g(h2,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            temp112=self.projection(h2,wvextend[:,:,0:n_dat-ns-1],ns)
            WL=weights_g0[2]
            F_rhs_g=(WL[po,0])*temp1+(WL[po,1])*temp2+(WL[po,2])*temp11+(WL[po,3])*temp12+(WL[po,4])*temp111+(WL[po,5])*temp112
        else:
            print('Not implemented')

        return F_rhs_g, weights_g0, v
    
    def neural_netrho(self,rho_extend,weights_g1,eps,wstiffg,v,n_dat,N_layers,Nx,dt,ns,po):
##################################################################################   
#                                                                                #
#        #              ######                            #                      #
#        #              #                                 #                      #
#  ##### #####  #####   ######   #####   #   #   ####   #####  #   #####  #####  #
#  #     #   #  #   #   #       #    #   #   #  #   #     #    #   #   #  #   #  #
#  #     #   #  #####   ######   #####   #####   #####    #    #   #####  #   #  #
#                                    #                                           #
#                                    ##                                          #
#                                    #                                           #
##################################################################################        
        if N_layers==0:
            WL=weights_g1[0]
            temp1=self.advection2g(rho_extend,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            F_rhs_rho=WL[po,0]*temp1#
        elif N_layers==1:
            W0=weights_g1[0]
            temp1=self.advection2g(rho_extend,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            h1=W0[po,0]*temp1
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            WL=weights_g1[1]
            F_rhs_rho=WL[po,0]*temp1+WL[po,2]*temp11
        elif N_layers==2:
            ns=1
            W0=weights_g1[0]
            temp1=self.advection2g(rho_extend,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            h1=W0[po,0]*temp1
            W1=weights_g1[1]
            temp11=self.advection2g(h1,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            h2=W1[po,0]*temp1+W1[po,2]*temp11
            temp111=self.advection2g(h2,vplusextend[:,:,0:n_dat-ns-1],vminusextend[:,:,0:n_dat-ns-1],vextend[:,:,0:n_dat-ns-1])
            WL=weights_g1[2]
            F_rhs_rho=(WL[po,0])*temp1+(WL[po,2])*temp11+(WL[po,4])*temp111
        else:
            print('Not implemented')
        return F_rhs_rho, weights_g1
     
    def firstderiv(self,g):
        out=(tf.roll(g,1,axis=1)-tf.roll(g,-1,axis=1))/(2.0*hx)
        return out
    
    def secondderiv(self,g):
        out=(tf.roll(g,1,axis=1)-2.0*g+tf.roll(g,-1,axis=1))/(hx*hx)
        return out
        
    def rhoOP(self,rhoextend,g):
        rhog=rhoextend*g
        return rhog
    
    def gOP(self,g,f):
        gf=g*f
        return gf
    
    def advection(self,g,vplusextend,vminusextend,vextend):
        advec=vextend*(tf.roll(g,1,axis=1)-tf.roll(g,-1,axis=1))/(2*hx)
        #        uxminustf=(g-tf.roll(g,1,axis=1))/hx
#        uxplustf=(tf.roll(g,-1,axis=1)-g)/hx
#        uxminustf=(3.0*g-4.0*tf.roll(g,1,axis=1)+1.0*tf.roll(g,2,axis=1))/(2.0*hx)
#        uxplustf=(-1.0*tf.roll(g,-2,axis=1)+4.0*tf.roll(g,-1,axis=1)-3.0*g)/(2.0*hx)                
#        uxminustf=(2.0*tf.roll(g,-1,axis=1)+3.0*g-6.0*tf.roll(g,1,axis=1)+1.0*tf.roll(g,2,axis=1))/(6.0*hx)
#        uxplustf=(-1.0*tf.roll(g,-2,axis=1)+6.0*tf.roll(g,-1,axis=1)-3.0*g-2.0*tf.roll(g,1,axis=1))/(6.0*hx)
#        advec=vplusextend*uxminustf+vminusextend*uxplustf
        return advec
    
    def advection2g(self,rho,none,none2,vextend):
        advec=vextend*(tf.roll(rho,1,axis=1)-tf.roll(rho,-1,axis=1))/(2*hx)
#        advec=vextend*(1/280*tf.roll(rho,4,axis=1)-4/105*tf.roll(rho,3,axis=1)+1/5*tf.roll(rho,2,axis=1)-4/5*tf.roll(rho,1,axis=1)+4/5*tf.roll(rho,-1,axis=1)-1/5*tf.roll(rho,-2,axis=1)+4/105*tf.roll(rho,-3,axis=1)-1/280*tf.roll(rho,-4,axis=1))/(hx)
#        rhox=(tf.roll(rho,-1,axis=1)-rho)/hx
#        advec=vextend*rhox
        return advec
    
    def advection2g2(self,rho,none,none2,vextend):
#        advec=vextend*(1/280*tf.roll(rho,4,axis=1)-4/105*tf.roll(rho,3,axis=1)+1/5*tf.roll(rho,2,axis=1)-4/5*tf.roll(rho,1,axis=1)+4/5*tf.roll(rho,-1,axis=1)-1/5*tf.roll(rho,-2,axis=1)+4/105*tf.roll(rho,-3,axis=1)-1/280*tf.roll(rho,-4,axis=1))/(hx)
#        rhox=(tf.roll(rho,-1,axis=1)-rho)/hx
        advec=vextend*(tf.roll(rho,1,axis=1)-tf.roll(rho,-1,axis=1))/(2*hx)
       # advec=vextend*rhox
        return advec
    
    
    def advection2(self,rho,vplusextend,vminusextend,vextend):
#        advec=vextend*(1/280*tf.roll(rho,4,axis=1)-4/105*tf.roll(rho,3,axis=1)+1/5*tf.roll(rho,2,axis=1)-4/5*tf.roll(rho,1,axis=1)+4/5*tf.roll(rho,-1,axis=1)-1/5*tf.roll(rho,-2,axis=1)+4/105*tf.roll(rho,-3,axis=1)-1/280*tf.roll(rho,-4,axis=1))/(hx)
        advec=vextend*(tf.roll(rho,1,axis=1)-tf.roll(rho,-1,axis=1))/(2*hx)
        #rhox=(rho-tf.roll(rho,1,axis=1))/hx#for rho equation
        #advec=vextend*rhox
#        uxminustf=(-1.0*tf.roll(rho,-2,axis=1)+4.0*tf.roll(rho,-1,axis=1)-3.0*rho)/(2.0*dx)
#        uxplustf=(3.0*rho-4.0*tf.roll(rho,1,axis=1)+1.0*tf.roll(rho,2,axis=1))/(2.0*dx)
#        uxplustf=(2.0*tf.roll(rho,-1,axis=1)+3.0*rho-6.0*tf.roll(rho,1,axis=1)+1.0*tf.roll(rho,2,axis=1))/(6.0*hx)
#        uxminustf=(-1.0*tf.roll(rho,-2,axis=1)+6.0*tf.roll(rho,-1,axis=1)-3.0*rho-2.0*tf.roll(rho,1,axis=1))/(6.0*hx)
#        advec=vplusextend*uxminustf+vminusextend*uxplustf
        return advec
    
    def projection(self,g,wvextend,ns):
        s=wvextend*g
        reduced=tf.math.reduce_sum(s/2.0,0)
        vv=tf.concat([reduced,reduced],0)
        for I in range(0,Nv-2):
            vv=tf.concat([vv,reduced],0)
        prj=tf.reshape(vv,[Nv,Nx,n_dat-ns-1])#wasn_dat-2
        return prj


    def net_uv(self,rho_extend,g,vextend,wvextend):

        ns=2
        wstiffg=self.wstiffg
        eps=(tf.math.tanh(wstiffg) + 1)*(max_epsilon-min_epsilon )/2+min_epsilon
        wstiffg2=self.wstiffg2
        
        if Max_orders==0:
            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)

            temp=4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3]
            
        elif Max_orders==1:
            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            temp1=4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3]

            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            temp2=(4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3])/eps
            
            temp=temp1+temp2
        elif Max_orders==2:
            
            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,0)
            temp1=4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3]

            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,1)
            temp2=(4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3])/eps

            k1_g, weights_g0, v = self.neural_netg(g[:,:,0:n_dat-2],self.weights_g0,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,2)
            k1_rho, weights_g1 = self.neural_netrho(rho_extend[:,:,0:n_dat-2],self.weights_g1,eps,self.wstiffg,self.v,self.n_dat,self.N_layers,self.Nx,self.dt,ns,2)
            temp3=(4/3*k1_g[:,:,1:n_dat-2]-2/3*k1_g[:,:,0:n_dat-3]+4/3*k1_rho[:,:,1:n_dat-2]-2/3*k1_rho[:,:,0:n_dat-3])/eps**2
            
            temp=temp1+temp2+temp3
        else:
            print('not yet implemented')
            
        u_g=g[:,:,2:n_dat-1]-4/3*g[:,:,1:n_dat-2]+1/3*g[:,:,0:n_dat-3]+dt*(temp)+2/3*dt*wstiffg2/(eps**2)*g[:,:,2:n_dat-1]

        u_rh=0*g

        ns=2
        Frhs_innerproduct=tf.math.reduce_sum(wvextend[:,:,0:n_dat-ns-1]*temp/2.0,0)
        
        return u_g,weights_g0,weights_g1,wstiffg,wstiffg2,Frhs_innerproduct,u_rh,eps    
    
    
    def callback(self, loss):
        print('Loss:', loss)
        
    def train(self, nIter):
        tf_dict = {self.g_tf: self.g,
                   self.rho_extend_tf: self.rho_extend,
                   self.vextend_tf: self.vextend,
                   self.wvextend_tf: self.wvextend}
        
        start_time = time.time()
        L=0
        for it in range(nIter):
            self.sess.run(self.train_op_Adam, tf_dict)
            # Print
            loss_value = self.sess.run(self.loss, tf_dict)
            Losss[L,0]=loss_value
            L=L+1
            if it % 10 == 0:
                elapsed = time.time() - start_time
                print('It: %d, Loss: %.3e, Time: %.2f' % 
                      (it, loss_value, elapsed))
                start_time = time.time()

#        self.optimizer.minimize(self.sess,
#                                feed_dict = tf_dict,
#                                fetches = [self.loss],
#                                loss_callback = self.callback)
            
    def predictrho(self,g):
        tf_dict = {self.g_tf: g,
                   self.rho_extend_tf: self.rho_extend,
                   self.vextend_tf: self.vextend,
                   self.wvextend_tf: self.wvextend}
        weights_g1=self.sess.run(self.weights_g1_tf)
        weights_g0=self.sess.run(self.weights_g0_tf)
        wstiff_g=self.sess.run(self.wstiff_g_tf)
        wstiff_g2=self.sess.run(self.wstiff_g2_tf)        
        return weights_g0,weights_g1,wstiff_g,wstiff_g2
    
if __name__ == "__main__":
    
    TTdata = scipy.io.loadmat('data_mm.mat')
    
    x = TTdata['x']
    rho_Data = TTdata['u']
    gData = TTdata['g']
    v = TTdata['v']
    wv=TTdata['wv']
    dt=TTdata['dt']
    hx=TTdata['hx']

    flag=0
    if flag==1:
        Wdata0 = scipy.io.loadmat('W_bdf0.mat')
        weightsg0inp=Wdata0['weightsg0']

        Wdata1=scipy.io.loadmat('W_bdf1.mat')
        weightsg1inp=Wdata1['weightsg1']
        
        Wdata2=scipy.io.loadmat('W_bdf2.mat')
        weightsg2inp=Wdata2['weightsg2']

        Wdatas=scipy.io.loadmat('W_stiff_bdf')
        wstiffginp=Wdatas['wstiffg']
        
        Wdatas=scipy.io.loadmat('W_stiff_bdf2')
        wstiffginp=Wdatas['wstiffg2']
    else:
        weightsg0inp=0.0
        weightsg1inp=0.0
        weightsg2inp=0.0
        weightsrho0inp=0.0
        weightsrho1inp=0.0
        biasesg0inp=0.0
        biasesg1inp=0.0
        biasesrho0inp=0.0
        biasesrho1inp=0.0
        wstiffginp=0.0
        wstiffrhoinp=0.0
        wstiffginp2=0.0

            
    Nv,Nx,n=gData.shape
    
    xx=x    
    
    nskip=1
    n_start=round(0.5*n/3.0)
    n_end=round(2.75*n/3.0)
    n_dat_temp=n_end-n_start
    n_dat=round(n_dat_temp/nskip)
    T_final=n*dt
    dt=nskip*dt
    
    N_layers=2
    Max_orders=2
         
    choose_order=1
    
    if choose_order==1:
        g=np.zeros([Nv,Nx,n_dat], dtype=float)
        rho=np.zeros([Nx,n_dat], dtype=float)
        rho_extend=np.zeros([Nv,Nx,n_dat], dtype=float)
    else:
        g=np.zeros([Nv,Nx,n_dat], dtype=float)

    for K in range(0,n_dat):
        for I in range(0,Nv):
            for J in range(0,Nx):
                g[I,J,K]=gData[I,J,nskip*(K)+n_start]
    
    for K in range(0,n_dat):
        for J in range(0,Nx):
            rho[J,K]=rho_Data[J,nskip*(K)+n_start]
            
    wv=np.float32(wv)
    
    rho = np.float32(rho)

    vextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                vextend[I,J,K]=v[I,0]
                
    wvextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                wvextend[I,J,K]=wv[I,0]

    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                rho_extend[I,J,K]=rho[J,K]

    vextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                vextend[I,J,K]=v[I,0]
    
    xv=np.zeros([Nv,1],dtype=float)
    for I in range(0,Nv):
        xv[I,0]=-1.0+2.0/(Nv-1)*(I)
        
        
    v=np.float32(v)

    ns=2
 
    vplus=np.zeros([Nv,1],dtype=float)
    vminus=np.zeros([Nv,1],dtype=float)
    for j in range(0,Nv):
        if v[j]>0:            
            vplus[j,0]=v[j,0]
        else:
            vminus[j,0]=v[j,0]
    vplus=np.float32(vplus)
    vminus=np.float32(vminus)
    vplusextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    vminusextend=np.zeros([Nv,Nx,n_dat],dtype=float)
    for I in range(0,Nv):
        for J in range(0,Nx):
            for K in range(0,n_dat):
                vplusextend[I,J,K]=vplus[I,0]
                vminusextend[I,J,K]=vminus[I,0]   
    
    N_s=3
    A1=np.zeros([N_s,N_s],dtype=float)
    c1=np.zeros([N_s,1],dtype=float)
    w1=np.zeros([N_s,1],dtype=float)

    A2=np.zeros([N_s,N_s],dtype=float)
    c2=np.zeros([N_s,1],dtype=float)
    w2=np.zeros([N_s,1],dtype=float)

    #IMEX RK ARS(2,2,2)
    gamma=1.0-np.sqrt(2.0)/2.0
    delta=1.0-1.0/(2.0*gamma)
    A1[1,0]=gamma
    A1[2,0]=delta
    A1[2,1]=1.0-delta
    w1[0,0]=delta
    w1[1,0]=1.0-delta
    w1[2,0]=0.0

    A2[1,1]=gamma
    A2[2,1]=1.0-gamma
    A2[2,2]=gamma
    w2[0,0]=0.0
    w2[1,0]=1.0-gamma
    w2[2,0]=gamma
    
    
    max_epsilon=0.1
    min_epsilon=0.001
    
    Nsteps=80000
    Losss=np.zeros([Nsteps,1],dtype=float)
    Losss_domain=np.zeros([Nsteps,1],dtype=float)
    for I in range(0,Nsteps):
        Losss_domain[I,0]=I
    
    
    modelrho = PDE_CLASSIFY(rho_extend,g,n_dat,N_layers,Nx,dt,hx,v,vextend,vplus,vplusextend,vminus,vminusextend,wv,wvextend,A1,A2,w1,w2,flag,max_epsilon,min_epsilon,weightsg0inp,weightsg1inp,weightsg2inp,wstiffginp,wstiffginp2,Max_orders,Losss)

    start_time = time.time()
    modelrho.train(Nsteps)
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    weightsg0,weightsg1,wstiffg,wstiffg2= modelrho.predictrho(g)
    
    LLosss=np.zeros([Nsteps,1],dtype=float)
    for I in range(0,Nsteps):
        LLosss[I,0]=np.log(Losss[I,0])

    fig = plt.figure()
    plt.scatter(Losss_domain,LLosss, color='black', linewidth=2, label='Log of Loss vs Number of Iterations')
    plt.show()
    plt.legend()
    fig.savefig('LossBDF2_example1.png')
    
    savemat('Loss2.mat',{'L_domain':Losss_domain, 'Loss_y':LLosss})
    
    
    
    

    u_pred_ndat=np.zeros([Nx,1],dtype=float)

    eps=(np.tanh(wstiffg) + 1)*(max_epsilon-min_epsilon)/2+min_epsilon
    
    c_g,c_v_g_x,pvgx=coeffsg(weightsg0,N_layers,eps)
    c_rho,c_v_rho_x=coeffsrho(weightsg1,N_layers,eps)
    print('The learned G-equation is:')
    print(c_g+wstiffg2/eps**2,'g +',c_v_g_x,'v*g_x+',pvgx,'<vg_x>')
    print(c_rho,'rho +',c_v_rho_x,'v*rho_x+')
        
    

#    savemat('W_bdf0',{'weightsg0':weightsg0})
#    savemat('W_bdf1',{'weightsg1':weightsg1})
#    savemat('W_stiff_bdf',{'wstiffg':wstiffg})
#    savemat('W_stiff_bdf2',{'wstiffg2':wstiffg2})
# Out:
# WARNING:tensorflow:From C:\Users\Ricardo\miniconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
#
# It: 0, Loss: 9.286e+00, Time: 2.71
# It: 10, Loss: 8.969e+00, Time: 0.36
# It: 20, Loss: 8.662e+00, Time: 0.36
# It: 30, Loss: 8.367e+00, Time: 0.37
# It: 40, Loss: 8.083e+00, Time: 0.35
# It: 50, Loss: 7.810e+00, Time: 0.36
# It: 60, Loss: 7.547e+00, Time: 0.36
# It: 70, Loss: 7.295e+00, Time: 0.37
# It: 80, Loss: 7.053e+00, Time: 0.35
# It: 90, Loss: 6.821e+00, Time: 0.35
# It: 100, Loss: 6.597e+00, Time: 0.36
# It: 110, Loss: 6.381e+00, Time: 0.36
# ...
